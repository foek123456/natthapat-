# %% [markdown]
# # SC 612 104 Essential Data Science
# ## คาบที่ 11: Data Visualization — matplotlib, seaborn, และ Visualization for Insight
#
# **ผู้สอน:** อ.ดร.พิชญา วิรัชโชติเสถียร (Pitchaya Wiratchotisatian)
# **ภาควิชาสถิติ คณะวิทยาศาสตร์ มหาวิทยาลัยขอนแก่น**
#
# ---

# %% [markdown]
# ### เนื้อหาในคาบนี้
#
# **ส่วนที่ 1: matplotlib พื้นฐาน**
#
# 1. Line Chart, Scatter Plot, Bar Chart, Histogram
# 2. Title, Label, Legend, Style
#
# **ส่วนที่ 2: เครื่องมือขั้นสูงกว่า**
#
#  3. Subplot — วางกราฟหลายอันในภาพเดียว
#  4. `pandas.plot()` — plot ตรงจาก DataFrame
#  5. seaborn: Boxplot, Heatmap (Correlation), Pairplot
#
# **ส่วนที่ 3: Visualization for Insight**
#
# 6. เลือก Chart Type ให้เหมาะกับข้อมูล
# 7. ตั้งชื่อกราฟให้สื่อความหมาย
# 8. Storytelling เบื้องต้นด้วยข้อมูล
#
# **แบบฝึกหัดท้ายคาบ**
#
# > 📁 **ไฟล์ที่ต้องใช้ในคาบนี้:** `world_weather_sample.csv`, `city_info.csv`, `region_info.csv`

# %%
import pandas as pd
import numpy as np
import os, shutil
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

# %%
# 1. ติดตั้งฟอนต์ภาษาไทย
# !apt-get -y install fonts-thai-tlwg

# 2. ล้าง cache ของ matplotlib เพื่ออัปเดตฟอนต์ใหม่
cache_dir = matplotlib.get_cachedir()
if os.path.exists(cache_dir):
    shutil.rmtree(cache_dir)

# 3. ลงทะเบียนฟอนต์ใหม่เข้ากับ FontManager
font_path = '/usr/share/fonts/truetype/tlwg/Loma.ttf'
if os.path.exists(font_path):
    fm.fontManager.addfont(font_path)

# 4. ตั้งค่าฟอนต์หลัก
plt.rcParams['font.family'] = 'Loma'
plt.rcParams['axes.unicode_minus'] = False

# 5. สร้างข้อมูลจำลองและแสดงผล
data = {
    'เมือง': ['กรุงเทพฯ', 'เชียงใหม่', 'ภูเก็ต'],
    'อุณหภูมิ': [30.5, 25.2, 28.9]
}
df_thai = pd.DataFrame(data)

print("ตั้งค่าระบบฟอนต์ภาษาไทยสำเร็จ!")

plt.figure(figsize=(8, 5))
plt.bar(df_thai['เมือง'], df_thai['อุณหภูมิ'], color='skyblue')
plt.title('กราฟแสดงอุณหภูมิแต่ละเมือง', fontsize=16)
plt.xlabel('ชื่อเมือง', fontsize=12)
plt.ylabel('อุณหภูมิ (องศาเซลเซียส)', fontsize=12)
plt.show()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-tlwg-garuda fonts-tlwg-garuda-ttf fonts-tlwg-kinnari
#   fonts-tlwg-kinnari-ttf fonts-tlwg-laksaman fonts-tlwg-laksaman-ttf
#   fonts-tlwg-loma fonts-tlwg-loma-ttf fonts-tlwg-mono fonts-tlwg-mono-ttf
#   fonts-tlwg-norasi fonts-tlwg-norasi-ttf fonts-tlwg-purisa
#   fonts-tlwg-purisa-ttf fonts-tlwg-sawasdee fonts-tlwg-sawasdee-ttf
#   fonts-tlwg-typewriter fonts-tlwg-typewriter-ttf fonts-tlwg-typist
#   fonts-tlwg-typist-ttf fonts-tlwg-typo fonts-tlwg-typo-ttf fonts-tlwg-umpush
#   fonts-tlwg-umpush-ttf fonts-tlwg-waree fonts-tlwg-waree-ttf
# The following NEW packages will be installed:
#   fonts-thai-tlwg fonts-tlwg-garuda fonts-tlwg-garuda-ttf fonts-tlwg-kinnari
#   fonts-tlwg-kinnari-ttf fonts-tlwg-laksaman fonts-tlwg-laksaman-ttf
#   fonts-tlwg-loma fonts-tlwg-loma-ttf fonts-tlwg-mono fonts-tlwg-mono-ttf
#   fonts-tlwg-norasi fonts-tlwg-norasi-ttf fonts-tlwg-purisa
#   fonts-tlwg-purisa-ttf fonts-tlwg-sawasdee fonts-tlwg-sawasdee-ttf
#   fonts-tlwg-typewriter fonts-tlwg-typewriter-ttf fonts-tlwg-typist
#   fonts-tlwg-typist-ttf fonts-tlwg-typo fonts-tlwg-typo-ttf fonts-tlwg-umpush
#   fonts-tlwg-umpush-ttf fonts-tlwg-waree fonts-tlwg-waree-ttf
# 0 upgraded, 27 newly installed, 0 to remove and 3 not upgraded.
# Need to get 2,805 kB of archives.
# After this operation, 6,974 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-garuda-ttf all 1:0.7.3-1 [152 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-garuda all 1:0.7.3-1 [4,360 B]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-kinnari-ttf all 1:0.7.3-1 [290 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-kinnari all 1:0.7.3-1 [4,362 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-laksaman-ttf all 1:0.7.3-1 [192 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-laksaman all 1:0.7.3-1 [4,346 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-loma-ttf all 1:0.7.3-1 [170 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-loma all 1:0.7.3-1 [4,102 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-mono-ttf all 1:0.7.3-1 [175 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-mono all 1:0.7.3-1 [4,072 B]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-norasi-ttf all 1:0.7.3-1 [331 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-norasi all 1:0.7.3-1 [4,082 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-purisa-ttf all 1:0.7.3-1 [313 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-purisa all 1:0.7.3-1 [3,556 B]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-sawasdee-ttf all 1:0.7.3-1 [171 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-sawasdee all 1:0.7.3-1 [3,574 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typewriter-ttf all 1:0.7.3-1 [178 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typewriter all 1:0.7.3-1 [3,630 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typist-ttf all 1:0.7.3-1 [177 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typist all 1:0.7.3-1 [4,066 B]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typo-ttf all 1:0.7.3-1 [177 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typo all 1:0.7.3-1 [4,106 B]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-umpush-ttf all 1:0.7.3-1 [236 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-umpush all 1:0.7.3-1 [4,340 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-waree-ttf all 1:0.7.3-1 [178 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-waree all 1:0.7.3-1 [4,092 B]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-thai-tlwg all 1:0.7.3-1 [9,356 B]
# Fetched 2,805 kB in 2s (1,204 kB/s)
# Selecting previously unselected package fonts-tlwg-garuda-ttf.
# (Reading database ... 118243 files and directories currently installed.)
# Preparing to unpack .../00-fonts-tlwg-garuda-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-garuda-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-garuda.
# Preparing to unpack .../01-fonts-tlwg-garuda_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-garuda (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-kinnari-ttf.
# Preparing to unpack .../02-fonts-tlwg-kinnari-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-kinnari-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-kinnari.
# Preparing to unpack .../03-fonts-tlwg-kinnari_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-kinnari (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-laksaman-ttf.
# Preparing to unpack .../04-fonts-tlwg-laksaman-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-laksaman-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-laksaman.
# Preparing to unpack .../05-fonts-tlwg-laksaman_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-laksaman (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-loma-ttf.
# Preparing to unpack .../06-fonts-tlwg-loma-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-loma.
# Preparing to unpack .../07-fonts-tlwg-loma_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-mono-ttf.
# Preparing to unpack .../08-fonts-tlwg-mono-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-mono-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-mono.
# Preparing to unpack .../09-fonts-tlwg-mono_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-mono (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-norasi-ttf.
# Preparing to unpack .../10-fonts-tlwg-norasi-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-norasi-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-norasi.
# Preparing to unpack .../11-fonts-tlwg-norasi_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-norasi (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-purisa-ttf.
# Preparing to unpack .../12-fonts-tlwg-purisa-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-purisa-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-purisa.
# Preparing to unpack .../13-fonts-tlwg-purisa_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-purisa (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-sawasdee-ttf.
# Preparing to unpack .../14-fonts-tlwg-sawasdee-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-sawasdee-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-sawasdee.
# Preparing to unpack .../15-fonts-tlwg-sawasdee_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-sawasdee (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typewriter-ttf.
# Preparing to unpack .../16-fonts-tlwg-typewriter-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typewriter-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typewriter.
# Preparing to unpack .../17-fonts-tlwg-typewriter_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typewriter (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typist-ttf.
# Preparing to unpack .../18-fonts-tlwg-typist-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typist-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typist.
# Preparing to unpack .../19-fonts-tlwg-typist_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typist (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typo-ttf.
# Preparing to unpack .../20-fonts-tlwg-typo-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typo-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typo.
# Preparing to unpack .../21-fonts-tlwg-typo_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typo (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-umpush-ttf.
# Preparing to unpack .../22-fonts-tlwg-umpush-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-umpush-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-umpush.
# Preparing to unpack .../23-fonts-tlwg-umpush_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-umpush (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-waree-ttf.
# Preparing to unpack .../24-fonts-tlwg-waree-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-waree-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-waree.
# Preparing to unpack .../25-fonts-tlwg-waree_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-waree (1:0.7.3-1) ...
# Selecting previously unselected package fonts-thai-tlwg.
# Preparing to unpack .../26-fonts-thai-tlwg_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-thai-tlwg (1:0.7.3-1) ...
# Setting up fonts-tlwg-garuda-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-laksaman-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-loma-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-typo-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-kinnari-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-umpush-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-kinnari (1:0.7.3-1) ...
# Setting up fonts-tlwg-laksaman (1:0.7.3-1) ...
# Setting up fonts-tlwg-sawasdee-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-typist-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-typewriter-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-garuda (1:0.7.3-1) ...
# Setting up fonts-tlwg-norasi-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-waree-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-loma (1:0.7.3-1) ...
# Setting up fonts-tlwg-purisa-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-mono-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-typewriter (1:0.7.3-1) ...
# Setting up fonts-tlwg-typo (1:0.7.3-1) ...
# Setting up fonts-tlwg-waree (1:0.7.3-1) ...
# Setting up fonts-tlwg-sawasdee (1:0.7.3-1) ...
# Setting up fonts-tlwg-typist (1:0.7.3-1) ...
# Setting up fonts-tlwg-umpush (1:0.7.3-1) ...
# Setting up fonts-tlwg-mono (1:0.7.3-1) ...
# Setting up fonts-tlwg-purisa (1:0.7.3-1) ...
# Setting up fonts-tlwg-norasi (1:0.7.3-1) ...
# Setting up fonts-thai-tlwg (1:0.7.3-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# ตั้งค่าระบบฟอนต์ภาษาไทยสำเร็จ!

# %% [markdown]
# ---
# ## 0. เตรียมข้อมูล: Merge + Clean
#
# ก่อนสร้างกราฟ เราจะ **merge 3 ตาราง** เข้าด้วยกัน แล้ว **ทำความสะอาด** เพื่อให้กราฟที่ได้สื่อความหมายจริง ไม่ถูกบิดเบือนจากข้อมูลสกปรก

# %%
# โหลดข้อมูลทั้ง 3 ไฟล์
df = pd.read_csv("https://raw.githubusercontent.com/PitchayaW/SC-612-104-Essential-Data-Science/420c1e19f9a749bb8ba041868d93fde8b4ec679b/Module-A-Notebooks/Dataset/world_weather_sample.csv")
df["date"] = pd.to_datetime(df["date"])
city_info = pd.read_csv("https://raw.githubusercontent.com/PitchayaW/SC-612-104-Essential-Data-Science/420c1e19f9a749bb8ba041868d93fde8b4ec679b/Module-A-Notebooks/Dataset/city_info.csv")
region_info = pd.read_csv("https://raw.githubusercontent.com/PitchayaW/SC-612-104-Essential-Data-Science/420c1e19f9a749bb8ba041868d93fde8b4ec679b/Module-A-Notebooks/Dataset/region_info.csv")

# Merge 3 ตารางเข้าด้วยกัน (เทคนิคจาก Session 9)
data = (
    df
    .merge(city_info[["city", "population_millions", "timezone"]], on="city", how="left")
    .merge(region_info, on="region", how="left")
)
print("ขนาดข้อมูลหลัง merge:", data.shape)
data.head()
# Out:
# ขนาดข้อมูลหลัง merge: (2075, 14)
#    record_id       date         city       country         region  \
# 0        983 2025-03-24     New York           USA  North America
# 1        220 2025-02-09        Tokyo         Japan           Asia
# 2       1022 2025-02-01  Los Angeles           USA  North America
# 3        469 2025-01-19       Mumbai         India           Asia
# 4       1834 2025-02-03    Cape Town  South Africa         Africa
#
#    temperature_c  humidity_pct  rainfall_mm  wind_speed_kmh  pressure_hpa  \
# 0           15.7          72.6          6.3            15.9        1005.4
# 1           18.3          60.6          0.0            20.5        1015.1
# 2           20.6          46.8          1.2             8.6        1013.5
# 3           31.0          73.4          8.0            11.8        1000.1
# 4           19.1          55.0          0.0            16.6        1015.1
#
#    population_millions  timezone continent_code  avg_gdp_growth_pct
# 0                  8.3     UTC-5            NAM                 2.3
# 1                 13.9     UTC+9             AS                 4.2
# 2                  3.9     UTC-8            NAM                 2.3
# 3                 20.4  UTC+5:30             AS                 4.2
# 4                  4.6     UTC+2             AF                 3.6

# %%
# ทำความสะอาดข้อมูล

# 1. ลบแถวที่ temperature_c ผิดปกติอย่างรุนแรง (นอกช่วงที่เป็นไปได้ทางฟิสิกส์)
data = data[(data["temperature_c"].isnull()) | (data["temperature_c"].between(-60, 60))]

# 2. Cap ค่า humidity_pct ให้อยู่ในช่วง 0-100 และ wind_speed_kmh ให้ไม่ติดลบ
data["humidity_pct"] = data["humidity_pct"].clip(lower=0, upper=100)
data["wind_speed_kmh"] = data["wind_speed_kmh"].clip(lower=0)

# 3. Fill missing values ที่เหลือด้วย median (ทนทานต่อ outliers ที่เหลือ)
numeric_cols = ["temperature_c", "humidity_pct", "rainfall_mm", "wind_speed_kmh", "pressure_hpa"]
for col in numeric_cols:
    data[col] = data[col].fillna(data[col].median())

# 4. ลบแถวซ้ำ
data = data.drop_duplicates()

# 5. ทำให้ตัวพิมพ์ของ country สม่ำเสมอ
data["country"] = data["country"].str.title()

print("ขนาดข้อมูลหลังทำความสะอาด:", data.shape)
print("\nMissing values ที่เหลือ:")
print(data[numeric_cols].isnull().sum())
data.describe()[numeric_cols].round(1)
# Out:
# ขนาดข้อมูลหลังทำความสะอาด: (2065, 14)
#
# Missing values ที่เหลือ:
# temperature_c     0
# humidity_pct      0
# rainfall_mm       0
# wind_speed_kmh    0
# pressure_hpa      0
# dtype: int64
#        temperature_c  humidity_pct  rainfall_mm  wind_speed_kmh  pressure_hpa
# count         2065.0        2065.0       2065.0          2065.0        2065.0
# mean            20.5          66.7          4.1            14.8        1013.1
# min             -0.2          21.5          0.0             0.0         993.9
# 25%             15.5          59.0          0.4            10.9        1009.4
# 50%             20.0          67.1          3.5            15.0        1013.1
# 75%             25.6          75.1          6.5            18.6        1017.2
# max             39.2         100.0         17.6            33.7        1030.6
# std              7.2          12.5          3.8             5.8           5.8

# %% [markdown]
# **ตอนนี้ `data` คือ DataFrame ที่สะอาดและพร้อมใช้สร้างกราฟแล้ว** — จะใช้ตัวแปรนี้ตลอดทั้ง Notebook

# %% [markdown]
# ---
# # ส่วนที่ 1: matplotlib พื้นฐาน

# %% [markdown]
# ## ทำไมต้องมี Data Visualization?
#
# `.describe()`, `.groupby()` ที่เรียนมาให้ "ตัวเลข" แต่สมองมนุษย์มองเห็น**รูปแบบ (pattern)** ได้ดีกว่าจากภาพมากกว่าตัวเลขล้วนๆ — กราฟที่ดีช่วยให้:
# - เห็นแนวโน้ม ความสัมพันธ์ และความผิดปกติได้เร็วกว่าอ่านตาราง
# - สื่อสารผลการวิเคราะห์ให้คนอื่นเข้าใจได้ง่าย (ไม่ใช่ทุกคนถนัดอ่านตัวเลข)
# - ตรวจสอบสมมติฐานเบื้องต้นก่อนทำการวิเคราะห์เชิงลึก
#
# **matplotlib** คือไลบรารีพื้นฐานที่สุดสำหรับสร้างกราฟด้วย Python — ไลบรารีอื่น (รวมถึง seaborn และ `pandas.plot()`) ต่างก็สร้างอยู่บน matplotlib ทั้งสิ้น

# %% [markdown]
# ## ชนิดกราฟพื้นฐานใน `matplotlib` และฟังก์ชันที่ใช้
#
# | ชนิดกราฟ | ฟังก์ชัน `matplotlib.pyplot` | คำอธิบาย |
# |---|---|---|
# | **Line Chart** | `plt.plot()` | แสดงแนวโน้มตามเวลา หรือลำดับที่มีความต่อเนื่อง |
# | **Scatter Plot** | `plt.scatter()` | แสดงความสัมพันธ์ระหว่าง 2 ตัวแปรตัวเลข |
# | **Bar Chart** | `plt.bar()` (แนวตั้ง), `plt.barh()` (แนวนอน) | เปรียบเทียบค่าระหว่างกลุ่มหมวดหมู่ |
# | **Histogram** | `plt.hist()` | แสดงการกระจายตัวของข้อมูลตัวเลข 1 คอลัมน์ |
# | **Boxplot** | `plt.boxplot()` | เปรียบเทียบการกระจายตัวระหว่างกลุ่ม และตรวจหา outliers |
# | **Subplots** | `plt.subplots()` | จัดวางกราฟหลายอันในภาพเดียว เพื่อเปรียบเทียบมุมมองที่แตกต่างกัน |

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Line Chart — กราฟเส้น
#
#
# ใช้แสดง**แนวโน้มตามเวลา** หรือลำดับที่มีความต่อเนื่อง — เหมาะกับข้อมูล time series ที่สุด

# %%
bangkok = data[data["city"] == "Bangkok"].sort_values("date")

# %%
bangkok
# Out:
#       record_id       date     city   country region  temperature_c  \
# 1348          1 2025-01-01  Bangkok  Thailand   Asia           31.3
# 1358          2 2025-01-02  Bangkok  Thailand   Asia           29.6
# 84            3 2025-01-03  Bangkok  Thailand   Asia           29.0
# 402           4 2025-01-04  Bangkok  Thailand   Asia           28.9
# 802           5 2025-01-05  Bangkok  Thailand   Asia           34.0
# ...         ...        ...      ...       ...    ...            ...
# 1445         86 2025-03-27  Bangkok  Thailand   Asia           37.4
# 108          87 2025-03-28  Bangkok  Thailand   Asia           31.0
# 1498         88 2025-03-29  Bangkok  Thailand   Asia           34.2
# 792          89 2025-03-30  Bangkok  Thailand   Asia           35.0
# 1398         90 2025-03-31  Bangkok  Thailand   Asia           35.7
#
#       humidity_pct  rainfall_mm  wind_speed_kmh  pressure_hpa  \
# 1348          73.9         10.6            24.1        1011.6
# 1358          87.6         11.1            12.2        1016.3
# 84            71.3          9.0             3.5        1002.7
# 402           66.9          9.3             9.6        1004.5
# 802           73.2          8.3             6.5        1009.7
# ...            ...          ...             ...           ...
# 1445          67.3         10.7            21.4        1002.4
# 108           58.7          6.9            19.3        1022.0
# 1498          88.0          2.5             4.8        1012.7
# 792           74.7          0.0            14.5        1005.2
# 1398          67.1          4.2            11.9        1006.6
#
#       population_millions timezone continent_code  avg_gdp_growth_pct
# 1348                 10.7    UTC+7             AS                 4.2
# 1358                 10.7    UTC+7             AS                 4.2
# 84                   10.7    UTC+7             AS                 4.2
# 402                  10.7    UTC+7             AS                 4.2
# 802                  10.7    UTC+7             AS                 4.2
# ...                   ...      ...            ...                 ...
# 1445                 10.7    UTC+7             AS                 4.2
# 108                  10.7    UTC+7             AS                 4.2
# 1498                 10.7    UTC+7             AS                 4.2
# 792                  10.7    UTC+7             AS                 4.2
# 1398                 10.7    UTC+7             AS                 4.2
#
# [90 rows x 14 columns]

# %%
plt.figure(figsize=(10, 5))
plt.plot(bangkok["date"], bangkok["temperature_c"])
plt.show()

# %% [markdown]
# **กราฟนี้ "ใช้งานได้" แต่ยังไม่ดี** — ไม่มีชื่อกราฟ ไม่มีชื่อแกน คนอื่นดูไม่รู้ว่ากราฟนี้คืออะไร หัวข้อถัดไป (Title/Label/Legend/Style) จะแก้ปัญหานี้

# %%
# กรองข้อมูลสำหรับเมือง London และเรียงตาม date แล้วสร้าง Line Chart
#ของความชื้นรายวันของเมือง London
London = data[data["city"] == "London"].sort_values("date")
plt.figure(figsize=(10, 5))
plt.plot(London["date"],London["humidity_pct"])
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Scatter Plot — กราฟจุดกระจาย
#
# ใช้แสดง**ความสัมพันธ์ระหว่าง 2 ตัวแปรตัวเลข** — แต่ละจุดคือ 1 record ของข้อมูล

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data["humidity_pct"], data["rainfall_mm"], alpha=0.3)
plt.show()

# %% [markdown]
# **🔍 สังเกต:** ลองดูรูปแบบการกระจายตัวของจุด — ความชื้นสูงกับปริมาณฝนมีความสัมพันธ์กันไหม? (alpha=0.3 ทำให้จุดโปร่งแสง เห็นความหนาแน่นของจุดที่ซ้อนกันได้ดีขึ้นเมื่อมีข้อมูลจำนวนมาก)

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Bar Chart — กราฟแท่ง
#
#
# ใช้เปรียบเทียบ**ค่าระหว่างกลุ่ม** (categorical) — เชื่อมกับ `groupby()` ที่เรียนมาจาก Session 9

# %%
avg_temp_by_region = data.groupby("region")["temperature_c"].mean().sort_values(ascending=False)

# %%
avg_temp_by_region

# %%
plt.figure(figsize=(10, 5))
plt.bar(avg_temp_by_region.index, avg_temp_by_region.values)
plt.show()

# %% [markdown]
# ### 3.1 Horizontal Bar Chart — เหมาะเมื่อชื่อกลุ่มยาว (อ่านง่ายกว่า)

# %%
avg_temp_by_city = data.groupby("city")["temperature_c"].mean().sort_values()

# %%
avg_temp_by_city
# Out:
# city
# Moscow           7.334444
# Toronto         11.800000
# Berlin          12.467778
# London          13.635556
# Paris           14.811236
# New York        15.476667
# Beijing         15.647778
# Auckland        17.804444
# Tokyo           18.450000
# Cape Town       19.162921
# Mexico City     19.187778
# Sydney          20.347778
# Buenos Aires    20.385393
# Los Angeles     20.650000
# Nairobi         21.413333
# Lima            21.490000
# Sao Paulo       22.810000
# Cairo           25.935556
# Lagos           29.177778
# Chiang Mai      29.650000
# Singapore       30.642045
# Mumbai          30.872222
# Bangkok         32.438889
# Name: temperature_c, dtype: float64

# %%
plt.figure(figsize=(8, 8))
plt.barh(avg_temp_by_city.index, avg_temp_by_city.values)
plt.show()

# %%
# คำนวณอุณหภูมิเฉลี่ยแยกตามทวีปและเรียงลำดับ

# สร้าง Bar Chart
avg_temp_by_region = data.groupby("region")["temperature_c"].mean().sort_values()
plt.figure(figsize=(8, 8))
plt.barh(avg_temp_by_region.index, avg_temp_by_region.values)
plt.show()

# %% [markdown]
# ---
# ## 4. Histogram — ฮิสโตแกรม
#
# ใช้แสดง**การกระจายตัว (distribution)** ของข้อมูลตัวเลข 1 คอลัมน์ — ต่างจาก bar chart ที่เทียบระหว่างกลุ่ม ฮิสโตแกรมแบ่ง "ช่วงค่า" (bins) แล้วนับว่ามีกี่ค่าตกอยู่ในแต่ละช่วง

# %%
plt.figure(figsize=(10, 5))
plt.hist(data["temperature_c"], bins=30)
plt.show()

# %% [markdown]
# **อ่านฮิสโตแกรมอย่างไร:** แกน x คือช่วงค่าของอุณหภูมิ แกน y คือ "จำนวนวัน/record" ที่อุณหภูมิตกอยู่ในช่วงนั้น — รูปทรงของฮิสโตแกรมบอกการกระจายตัว เช่น โค้งระฆัง (normal distribution), เบ้ซ้าย/ขวา (skewed), หรือมี 2 ยอด (bimodal — อาจบอกใบ้ว่าข้อมูลมี 2 กลุ่มย่อยซ่อนอยู่)
#
# ### 4.1 ปรับจำนวน `bins` ส่งผลต่อการตีความอย่างไร

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for ax, n_bins in zip(axes, [10, 30, 100]):
    ax.hist(data["temperature_c"], bins=n_bins)
    ax.set_title(f"bins={n_bins}")
plt.tight_layout()
plt.show()

# %% [markdown]
# **🔍 สังเกต:** `bins` น้อยเกินไป → เห็นภาพรวมหยาบเกินไป (อาจพลาดรายละเอียดสำคัญ) ส่วน `bins` มากเกินไป → เห็นแต่ noise จนมองไม่เห็นรูปแบบโดยรวม — ไม่มีค่าที่ "ถูกต้องที่สุด" ตายตัว ต้องลองปรับดูตามข้อมูลจริง

# %% [markdown]
# ---
# ## 5. Title, Label, Legend, Style — ทำให้กราฟ "สื่อความหมาย"

# %% [markdown]
# กราฟที่ผ่านมาทำงานถูกต้อง แต่**ไม่มีใครเข้าใจ**ถ้าไม่มีบริบท — องค์ประกอบ 4 อย่างนี้คือสิ่งที่กราฟทุกอันที่จะนำไปใช้จริง (รายงาน, นำเสนอ) ต้องมีเสมอ
#
# | องค์ประกอบ | คำสั่ง | หน้าที่ |
# |---|---|---|
# | **Title** | `plt.title()` | บอกว่ากราฟนี้คืออะไร |
# | **Label** | `plt.xlabel()`, `plt.ylabel()` | บอกว่าแต่ละแกนคือตัวแปรอะไร หน่วยอะไร |
# | **Legend** | `plt.legend()` | บอกว่าแต่ละเส้น/สี/จุด แทนอะไร (เมื่อมีหลายชุดข้อมูลในกราฟเดียว) |
# | **Style** | `color`, `linestyle`, `marker`, ฯลฯ | ช่วยแยกแยะและทำให้กราฟอ่านง่ายขึ้น |
#
# ### 5.1 ตัวอย่าง Line Chart ที่มีองค์ประกอบครบ

# %%
bangkok = data[data["city"] == "Bangkok"].sort_values("date")

plt.figure(figsize=(10, 5))
plt.plot(bangkok["date"], bangkok["temperature_c"], color="firebrick", linewidth=1.5)
plt.title("อุณหภูมิรายวันที่กรุงเทพฯ (มกราคม - มีนาคม 2025)")
plt.xlabel("วันที่")
plt.ylabel("อุณหภูมิ (°C)")
plt.xticks(rotation=30)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# **เทียบกับกราฟแรกที่ไม่มีองค์ประกอบเหล่านี้** — กราฟนี้ดูครั้งแรกก็เข้าใจได้ทันทีว่า "นี่คือกราฟอุณหภูมิรายวันของกรุงเทพฯ" โดยไม่ต้องถามใคร
#
# ### 5.2 Legend — เมื่อมีหลายชุดข้อมูลในกราฟเดียว
#
# ใส่ `label=` ตอนวาดกราฟแต่ละเส้น แล้วเรียก `plt.legend()` ตอนท้าย

# %%
cities_to_compare = ["Bangkok", "Tokyo", "London"]
colors = ["firebrick", "steelblue", "seagreen"]

plt.figure(figsize=(10, 5))
for city, color in zip(cities_to_compare, colors):
    city_data = data[data["city"] == city].sort_values("date")
    plt.plot(city_data["date"], city_data["temperature_c"], label=city, color=color)

plt.title("เปรียบเทียบอุณหภูมิรายวัน: Bangkok vs Tokyo vs London")
plt.xlabel("วันที่")
plt.ylabel("อุณหภูมิ (°C)")
plt.legend(title="เมือง")
plt.xticks(rotation=30)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.3 Style — ตัวเลือกการตกแต่งที่ใช้บ่อย
#
# | พารามิเตอร์ | ใช้กับกราฟ | ตัวอย่างค่า |
# |---|---|---|
# | `color` | ทุกกราฟ | `"red"`, `"#1f77b4"`, `"steelblue"` |
# | `linestyle` | line chart | `"-"` (ทึบ), `"--"` (ประ), `":"` (จุด) |
# | `marker` | line/scatter | `"o"` (กลม), `"s"` (สี่เหลี่ยม), `"^"` (สามเหลี่ยม) |
# | `alpha` | ทุกกราฟ | 0 (โปร่งใสหมด) ถึง 1 (ทึบหมด) |
# | `figsize` | ตอนสร้าง figure | `(กว้าง, สูง)` หน่วยนิ้ว |

# %%
plt.figure(figsize=(10, 5))

tokyo = data[data["city"] == "Tokyo"].sort_values("date")
plt.plot(tokyo["date"], tokyo["temperature_c"],
         color="darkorange", linestyle="--", marker="o", markersize=3, alpha=0.7)

plt.title("อุณหภูมิรายวันที่ Tokyo (พร้อม marker แต่ละจุดข้อมูล)")
plt.xlabel("วันที่")
plt.ylabel("อุณหภูมิ (°C)")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.4 ใช้ Style Sheet สำเร็จรูปของ matplotlib
#
# matplotlib มี theme สำเร็จรูปให้เลือกใช้ทั้งหน้า ไม่ต้องตั้งค่าทีละกราฟ

# %%
print("Style ที่มีให้เลือก (ตัวอย่างบางส่วน):", plt.style.available[:8])

current_font = plt.rcParams["font.family"]   # จำฟอนต์ปัจจุบันไว้ก่อน เพราะ style ใหม่อาจทับฟอนต์ไทยที่ตั้งไว้

with plt.style.context("seaborn-v0_8-whitegrid"):
    plt.rcParams["font.family"] = current_font   # ตั้งฟอนต์ไทยกลับคืนหลังเข้า style context
    plt.figure(figsize=(10, 5))
    plt.plot(bangkok["date"], bangkok["temperature_c"], color="firebrick")
    plt.title("อุณหภูมิรายวันที่กรุงเทพฯ (ใช้ style seaborn-v0_8-whitegrid)")
    plt.xlabel("วันที่")
    plt.ylabel("อุณหภูมิ (°C)")
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# > 💡 **เกร็ดเสริม:** ใช้ `with plt.style.context("ชื่อสไตล์"):` เพื่อใช้สไตล์นั้นแค่ในบล็อกโค้ดนี้ (ไม่กระทบกราฟอื่นที่จะวาดต่อไป) ถ้าอยากใช้ทั้ง Notebook ให้เรียก `plt.style.use("ชื่อสไตล์")` ครั้งเดียวตอนต้นไฟล์

# %% [markdown]
# ---
# # ส่วนที่ 2: เครื่องมือขั้นสูงกว่า
#
# ## 6. Subplot — วางกราฟหลายอันในภาพเดียว
#
# `plt.subplots(แถว, คอลัมน์)` สร้าง "กริด" ของกราฟย่อยหลายอันในภาพเดียว — มีประโยชน์มากเวลาต้องการเปรียบเทียบหลายมุมมองพร้อมกัน

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# axes เป็น array 2 มิติ (เชื่อมกับ NumPy ที่เรียนมา) เข้าถึงแต่ละช่องด้วย [แถว, คอลัมน์]
axes[0, 0].plot(bangkok["date"], bangkok["temperature_c"], color="firebrick")
axes[0, 0].set_title("อุณหภูมิรายวัน (Bangkok)")

axes[0, 1].hist(data["temperature_c"], bins=30, color="steelblue")
axes[0, 1].set_title("การกระจายตัวของอุณหภูมิ (ทุกเมือง)")

avg_temp_by_region = data.groupby("region")["temperature_c"].mean().sort_values(ascending=False)
axes[1, 0].bar(avg_temp_by_region.index, avg_temp_by_region.values, color="seagreen")
axes[1, 0].set_title("อุณหภูมิเฉลี่ยแยกตาม Region")
axes[1, 0].tick_params(axis="x", rotation=30)

axes[1, 1].scatter(data["humidity_pct"], data["rainfall_mm"], alpha=0.3, color="purple")
axes[1, 1].set_title("ความชื้น vs ปริมาณฝน")

plt.tight_layout()
plt.show()

# %% [markdown]
# **สังเกต:** เมื่อใช้ `plt.subplots()` ต้องเรียก `.set_title()`, `.set_xlabel()` แทน `plt.title()`, `plt.xlabel()` ปกติ (เพราะ `ax` แต่ละช่องเป็น object ของตัวเอง — เชื่อมกับ OOP/method ที่เรียนมา: `axes[0,0]` คือ object หนึ่ง มี method ของตัวเอง)
#
# ### 6.1 Subplot แบบแถวเดียว/คอลัมน์เดียว (ง่ายกว่าเวลาไม่ต้องการกริด 2 มิติ)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

cities_subset = ["Bangkok", "Tokyo", "London"]
for ax, city in zip(axes, cities_subset):
    city_data = data[data["city"] == city].sort_values("date")
    ax.plot(city_data["date"], city_data["temperature_c"])
    ax.set_title(city)
    ax.tick_params(axis="x", rotation=30)

plt.suptitle("เปรียบเทียบอุณหภูมิรายวัน 3 เมือง", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# > 💡 **เกร็ดเสริม:** `plt.suptitle()` ใส่ชื่อรวมให้ทั้งภาพ (เหนือกราฟย่อยทั้งหมด) ต่างจาก `ax.set_title()` ที่ใส่ชื่อให้กราฟย่อยแต่ละอัน

# %% [markdown]
# ---

# %% [markdown]
# ## 7. `pandas.plot()` — Plot โดยตรงจาก DataFrame
#
# pandas มีวิธี `.plot()` ติดตัวมาเลย ไม่ต้องเรียก `plt.plot()` แยก — สร้างกราฟเร็วกว่าตอนสำรวจข้อมูล (Exploratory Data Analysis) เพราะเขียนโค้ดน้อยกว่า
#
# **ข้อสำคัญ:** `.plot()` ของ pandas สร้างด้วย matplotlib เบื้องหลัง ดังนั้นยังใช้ `plt.title()`, `plt.xlabel()` ฯลฯ ต่อท้ายได้ตามปกติ

# %%
bangkok = data[data["city"] == "Bangkok"].sort_values("date")

bangkok.plot(x="date", y="temperature_c", figsize=(10, 5), color="firebrick")
plt.title("อุณหภูมิรายวันที่กรุงเทพฯ (วาดด้วย pandas.plot())")
plt.ylabel("อุณหภูมิ (°C)")
plt.tight_layout()
plt.show()

# %%
# Area chart
bangkok.plot(kind="area", x="date", y="temperature_c",
             figsize=(10, 5), color="firebrick", alpha=0.5)
# Out:
# <Axes: xlabel='date'>

# %%
# ลองทำดูหนูทำได้
# kind="line"
# วาดอุณหภูมิรายวันของเมือง "Tokyo" ด้วย .plot()
Tokyo = data[data["city"] == "Tokyo"].sort_values("date")
Tokyo.plot(x="date", y="temperature_c", figsize=(10, 5), color="firebrick")
plt.title("อุณหภูมิรายวันที่Tokyoฯ (วาดด้วย pandas.plot())")
plt.ylabel("อุณหภูมิ (°C)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.1 `pandas.plot()` กับ `kind=` — เลือกชนิดกราฟ
#
# พารามิเตอร์ `kind` กำหนดชนิดกราฟที่จะวาด — ทุกแบบเป็นสิ่งที่เคยเรียนมาแล้วใน matplotlib ตอนต้นคาบ เพียงแต่เรียกผ่าน DataFrame โดยตรง สั้นกว่ามาก
#
# | `kind=` | เทียบเท่า matplotlib | ใช้เมื่อ |
# |---|---|---|
# | `"line"` (default) | `plt.plot()` | ดูแนวโน้มตามเวลา/ลำดับ |
# | `"bar"` | `plt.bar()` | เปรียบเทียบค่าระหว่างกลุ่ม (แนวตั้ง) |
# | `"barh"` | `plt.barh()` | เปรียบเทียบค่าระหว่างกลุ่ม เมื่อชื่อกลุ่มยาว (แนวนอน) |
# | `"hist"` | `plt.hist()` | ดูการกระจายตัวของข้อมูล 1 คอลัมน์ |
# | `"scatter"` | `plt.scatter()` | ดูความสัมพันธ์ระหว่าง 2 ตัวแปร (ต้องระบุ `x=`, `y=` เสมอ) |
# | `"box"` | คล้าย `sns.boxplot()` | ดูการกระจายตัว + outliers เทียบหลายคอลัมน์/กลุ่ม |
# | `"area"` | พื้นที่ใต้เส้น (stacked ได้) | ดูสัดส่วนที่เปลี่ยนตามเวลา |
# | `"pie"` | กราฟวงกลม | ดูสัดส่วนของกลุ่ม ณ จุดเดียว (ใช้เมื่อกลุ่มไม่เยอะ) |
#
# ด้านล่างนี้จะไล่ดูตัวอย่างของแต่ละ `kind` ทีละแบบ

# %%
avg_temp_by_region = data.groupby("region")["temperature_c"].mean().sort_values(ascending=False)
avg_temp_by_region
# Out:
# region
# Asia             26.267286
# Africa           23.935655
# South America    21.566171
# Oceania          19.076111
# North America    16.778611
# Europe           12.054596
# Name: temperature_c, dtype: float64

# %%
avg_temp_by_region.plot(kind="bar", figsize=(10, 5), color="seagreen")
plt.title("อุณหภูมิเฉลี่ยแยกตาม Region (วาดด้วย pandas.plot(kind='bar'))")
plt.ylabel("อุณหภูมิเฉลี่ย (°C)")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
# ลองทำดูหนูทำได้
# kind="bar"
# หาความเร็วลมเฉลี่ย (wind_speed_kmh) แยกตาม region แล้ววาด bar chart
avg_wind_speed_kmh_region = data.groupby("region")["wind_speed_kmh"].mean().sort_values(ascending=False)
avg_wind_speed_kmh_region
avg_wind_speed_kmh_region.plot(kind="bar", figsize=(10, 5), color="seagreen")
plt.title("อุณหภูมิเฉลี่ยแยกตาม Region (วาดด้วย pandas.plot(kind='bar'))")
plt.ylabel("อุณหภูมิเฉลี่ย (°C)")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
data["temperature_c"].plot(kind="hist", bins=30,
                           figsize=(10, 5), color="steelblue")
plt.title("การกระจายตัวของอุณหภูมิ (วาดด้วย pandas.plot(kind='hist'))")
plt.xlabel("อุณหภูมิ (°C)")
plt.tight_layout()
plt.show()

# %%
# ลองทำดูหนูทำได้
# kind="hist"
# วาด histogram ของ data["temperature_c"].plot(kind="hist", bins=30,
data["temperature_c"].plot(kind="hist", bins=30,
                           figsize=(10, 5), color="pink")
plt.title("การกระจายตัวของอุณหภูมิ (วาดด้วย pandas.plot(kind='hist'))")
plt.xlabel("อุณหภูมิ (°C)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.1.1 `kind="barh"` — แนวนอน

# %%
avg_temp_by_city = data.groupby("city")["temperature_c"].mean().sort_values()
avg_temp_by_city
# Out:
# city
# Moscow           7.334444
# Toronto         11.800000
# Berlin          12.467778
# London          13.635556
# Paris           14.811236
# New York        15.476667
# Beijing         15.647778
# Auckland        17.804444
# Tokyo           18.450000
# Cape Town       19.162921
# Mexico City     19.187778
# Sydney          20.347778
# Buenos Aires    20.385393
# Los Angeles     20.650000
# Nairobi         21.413333
# Lima            21.490000
# Sao Paulo       22.810000
# Cairo           25.935556
# Lagos           29.177778
# Chiang Mai      29.650000
# Singapore       30.642045
# Mumbai          30.872222
# Bangkok         32.438889
# Name: temperature_c, dtype: float64

# %%
avg_temp_by_city.plot(kind="barh", figsize=(8, 8), color="slateblue")
plt.title("อุณหภูมิเฉลี่ยแยกตามเมือง (วาดด้วย pandas.plot(kind='barh'))")
plt.xlabel("อุณหภูมิเฉลี่ย (°C)")
plt.tight_layout()
plt.show()

# %%
# ลองทำดูหนูทำได้
# kind="barh"
# หาปริมาณฝนเฉลี่ย (rainfall_mm) แยกตาม country แล้ววาด barh
avg_rainfall_mm_city = data.groupby("country")["rainfall_mm"].sum().sort_values()
avg_rainfall_mm_city
avg_temp_by_city.plot(kind="barh", figsize=(8, 8), color="slateblue")
plt.title("ปริมาณฝนเฉลี่ยเเยกตามประเทศ (วาดด้วย pandas.plot(kind='barh'))")
plt.xlabel("ปริมาณฝนเฉลี่ย (°C)")
plt.tight_layout()
plt.show()

# %%
# kind="pie" — หาจำนวนเมืองในแต่ละ region (.value_counts())
#แล้ววาด pie chart
data['region'].value_counts().plot(kind='pie',
                                   autopct="%.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
region_counts = data['region'].value_counts()
region_counts
# Out:
# region
# Asia             538
# North America    360
# Africa           359
# Europe           359
# South America    269
# Oceania          180
# Name: count, dtype: int64

# %%
data['region'].value_counts()\
              .plot(kind='pie',
                    autopct = lambda pct: round(pct*region_counts.sum()/100))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### 7.1.2 `kind="scatter"` — ต้องระบุ `x=` และ `y=` เสมอ
#
# ต่างจาก `kind` อื่นๆ ตรงที่ `scatter` ต้องบอกว่าแกน x และแกน y คือคอลัมน์ไหน เพราะกราฟจุดต้องใช้ 2 ตัวแปรเสมอ

# %%
data.plot(kind="scatter", x="humidity_pct", y="rainfall_mm", alpha=0.3,
          figsize=(8, 6), color="teal")
plt.title("ความชื้น vs ปริมาณฝน (วาดด้วย pandas.plot(kind='scatter'))")
plt.xlabel("ความชื้น (%)")
plt.ylabel("ปริมาณฝน (mm)")
plt.tight_layout()
plt.show()

# %%
# ลองทำดูหนูทำได้
# kind="scatter"
# วาด scatter ระหว่าง wind_speed_kmh กับ pressure_hpa
data.plot(kind="scatter",x="wind_speed_kmh",y="pressure_hpa",alpha=0.3,color="red")
plt.title(" wind_speed_kmh กับ pressure_hpa(วาดด้วย pandas.plot(kind='scatter'))")
plt.xlabel("wind_speed_kmh")
plt.ylabel("pressure_hpa")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.1.3 `kind="box"` — Boxplot จากหลายคอลัมน์พร้อมกัน
#
# เมื่อเรียก `.plot(kind="box")` กับ DataFrame ที่มีหลายคอลัมน์ pandas จะวาด boxplot ของแต่ละคอลัมน์เทียบกันในภาพเดียว — สะดวกเวลาต้องการเทียบสเกล/การกระจายตัวของตัวแปรตัวเลขหลายตัวอย่างรวดเร็ว (ควรระวังเรื่องหน่วยที่ต่างกันด้วย)

# %%
data[["temperature_c", "humidity_pct", "wind_speed_kmh"]].plot(
    kind="box", figsize=(8, 6)
)
plt.title("เปรียบเทียบการกระจายตัว: temperature_c, humidity_pct, wind_speed_kmh")
plt.ylabel("ค่า (หน่วยต่างกัน — ดูรูปทรงการกระจายตัวเป็นหลัก)")
plt.tight_layout()
plt.show()

# %% [markdown]
# **🔍 สังเกต:** `kind="box"` ของ pandas สะดวกสำหรับดูภาพรวมเร็วๆ แต่ถ้าต้องการ boxplot ที่แยกตามกลุ่ม (เช่น แยกตาม `region` พร้อม `hue`) แบบที่ยืดหยุ่นกว่า ให้ใช้ `sns.boxplot()` จาก seaborn ในหัวข้อถัดไปแทน

# %%
# ลองทำดูหนูทำได้
# kind="box"
# วาด boxplot ของ rainfall_mm ทั้งหมดของเมือง Bangkok
rainfall_mm_Bangkok=data.groupby[["city"]=="Bangkok","rainfall_mm"].sort_values("date")

data[data[["city"]=="Bangkok"]].plot(
    kind="box", figsize=(8, 6))

plt.title("rainfall_mm ทั้งหมดของเมือง Bangkok")
plt.ylabel("ค่า (หน่วยต่างกัน — ดูรูปทรงการกระจายตัวเป็นหลัก)")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_584/1351000842.py in <cell line: 0>()
#       2 # kind="box"
#       3 # วาด boxplot ของ rainfall_mm ทั้งหมดของเมือง Bangkok
# ----> 4 rainfall_mm_Bangkok=data.groupby[["city"]=="Bangkok","rainfall_mm"].sort_values("date")
#       5
#       6 data[data[["city"]=="Bangkok"]].plot(
#
# TypeError: 'method' object is not subscriptable

# %% [markdown]
# ### 7.2 `pandas.plot()` กับหลายคอลัมน์พร้อมกัน (สร้าง Legend อัตโนมัติ)

# %%
monthly_avg = data.groupby(data["date"].dt.month)[["temperature_c", "humidity_pct"]].mean()
monthly_avg

# %%
monthly_avg.plot(figsize=(10, 5), marker="o")
plt.title("ค่าเฉลี่ยอุณหภูมิและความชื้นรายเดือน")
plt.xlabel("เดือน")
plt.ylabel("ค่าเฉลี่ย")
plt.legend(["อุณหภูมิ (°C)", "ความชื้น (%)"])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.2.1 Feature อื่นๆ ที่ใช้บ่อยของ `pandas.plot()`
#
# นอกจาก `kind=` แล้ว `.plot()` ยังมีพารามิเตอร์ที่ช่วยให้ปรับกราฟได้เร็วโดยไม่ต้องเขียน matplotlib เพิ่ม
#
# | พารามิเตอร์ | หน้าที่ |
# |---|---|
# | `subplots=True` | แยกแต่ละคอลัมน์เป็นกราฟย่อยของตัวเอง แทนที่จะรวมในกราฟเดียว |
# | `secondary_y=` | ย้ายบางคอลัมน์ไปใช้แกน y ด้านขวา — ใช้เมื่อตัวแปรมีสเกลต่างกันมาก |
# | `stacked=True` | ใช้กับ `kind="bar"`/`"area"` เพื่อวางซ้อนแทนวางเรียง — ดูสัดส่วนรวมได้ |
# | `rot=` | หมุนตัวหนังสือแกน x (แทน `plt.xticks(rotation=...)`) |
# | `xlim=`, `ylim=` | กำหนดขอบเขตของแกน เช่น `xlim=(0, 100)` |
# | `style=` | รูปแบบเส้น/marker แบบย่อ เช่น `"o--"` (จุด + เส้นประ) |
# | `grid=True` | แสดงเส้นตาราง (แทน `plt.grid()`) |

# %% [markdown]
# #### `subplots=True` — แยกกราฟย่อยอัตโนมัติ
#
# ต่างจากตัวอย่างก่อนหน้าที่ `temperature_c` กับ `humidity_pct` ถูกวาดรวมในกราฟเดียว (สเกลต่างกันทำให้เทียบยาก) `subplots=True` จะแยกให้อัตโนมัติ

# %%
monthly_avg.plot(subplots=True, figsize=(10, 6), layout=(2, 1), marker="o", legend=False)
plt.suptitle("ค่าเฉลี่ยรายเดือน แยกกราฟย่อยอัตโนมัติด้วย subplots=True", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### `secondary_y=` — ใช้แกน y สองข้างเมื่อสเกลต่างกันมาก
#
# อีกทางเลือกหนึ่งแทน `subplots=True`: วาดในกราฟเดียว แต่ให้บางคอลัมน์ใช้แกน y ด้านขวาแยกจากด้านซ้าย — เห็นทั้ง 2 เส้นในภาพเดียวโดยไม่ถูกสเกลที่ต่างกันบดบัง

# %%
monthly_avg.plot(figsize=(10, 5), marker="o",
                 secondary_y="humidity_pct")
plt.title("อุณหภูมิ (แกนซ้าย) vs ความชื้น (แกนขวา) รายเดือน — ใช้ secondary_y")
plt.xlabel("เดือน")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### `stacked=True` — Stacked Bar Chart
#
# ใช้เมื่อต้องการดูทั้ง "ยอดรวม" และ "สัดส่วนของแต่ละกลุ่มย่อย" ไปพร้อมกัน — ตัวอย่างนี้ดูจำนวนวันที่เป็นวันธรรมดา (`is_weekend=False`) กับวันหยุด (`is_weekend=True`) ในแต่ละ region

# %%
data["is_weekend"] = data["date"].dt.dayofweek >= 5

# %%
data.groupby(["region", "is_weekend"]).size()

# %%
weekend_by_region = data.groupby(["region", "is_weekend"]).size().unstack(fill_value=0)
weekend_by_region.columns = ["วันธรรมดา", "วันหยุดสุดสัปดาห์"]
weekend_by_region

# %%
weekend_by_region.plot(kind="bar", stacked=True, figsize=(10, 5),
                        color=["steelblue", "darkorange"], rot=30)
plt.title("จำนวน Record แยกตาม Region (วันธรรมดา vs วันหยุด) — Stacked Bar")
plt.ylabel("จำนวน record")
plt.tight_layout()
plt.show()

# %% [markdown]
# **🔍 สังเกต:** ถ้าใช้ `stacked=False` (ค่า default) แท่งของแต่ละกลุ่มย่อยจะถูกวางเรียงข้างกันแทนการซ้อน — ลองเปลี่ยนดูเพื่อเทียบว่าแบบไหนอ่านง่ายกว่าสำหรับคำถามที่ต้องการตอบ

# %% [markdown]
# ### 7.3 เปรียบเทียบ matplotlib ตรงๆ vs `pandas.plot()`
#
# | | matplotlib ตรงๆ | `pandas.plot()` |
# |---|---|---|
# | ความยาวโค้ด | ยาวกว่า ต้องระบุ x, y แยก | สั้นกว่า มาก สำหรับข้อมูลใน DataFrame |
# | ความยืดหยุ่น | ยืดหยุ่นที่สุด ปรับแต่งได้ทุกจุด | ยืดหยุ่นน้อยกว่าเล็กน้อย แต่ปรับแต่งต่อด้วย `plt.*` ได้ |
# | เหมาะกับ | กราฟที่ต้องการควบคุมรายละเอียดสูง, กราฟซับซ้อน | การสำรวจข้อมูลเร็วๆ (Exploratory Data Analysis) |

# %% [markdown]
# ---

# %% [markdown]
# ## 8. seaborn — กราฟสถิติที่สวยและใช้ง่ายขึ้น
#
# **seaborn** สร้างอยู่บน matplotlib แต่ออกแบบมาเฉพาะสำหรับ**กราฟเชิงสถิติ** — โค้ดสั้นกว่า สวยกว่า (มี theme ให้ default) และทำงานกับ DataFrame ได้ลื่นไหลกว่า (ส่ง `data=` และชื่อคอลัมน์ตรงๆ)

# %% [markdown]
# ### 8.1 Boxplot — ทวนจาก Data Cleaning notebook
#
# ใช้เปรียบเทียบการกระจายตัวระหว่างกลุ่ม และตรวจหา outliers (ตามที่เรียนมาแล้ว)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x="region", y="temperature_c")
plt.title("การกระจายตัวของอุณหภูมิ แยกตาม Region")
plt.xlabel("ภูมิภาค")
plt.ylabel("อุณหภูมิ (°C)")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.2 Boxplot พร้อมแยกสีตามกลุ่มย่อย (`hue`)
#
# `hue` ใส่มิติที่ 3 เข้าไปในกราฟ โดยใช้สีแยกกลุ่มย่อย — มีประโยชน์มากเวลาต้องการเปรียบเทียบ 2 มิติพร้อมกัน

# %%
data["is_weekend"] = data["date"].dt.dayofweek >= 5

plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x="region", y="temperature_c", hue="is_weekend")
plt.title("อุณหภูมิแยกตาม Region และวันธรรมดา/วันหยุด")
plt.xlabel("ภูมิภาค")
plt.ylabel("อุณหภูมิ (°C)")
plt.xticks(rotation=20)
plt.legend(title="วันหยุดสุดสัปดาห์")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 9. Heatmap Correlation — ความสัมพันธ์ระหว่างตัวแปร
#
# **Correlation (ค่าสหสัมพันธ์)** บอกว่าตัวแปร 2 ตัวมีความสัมพันธ์กันมากแค่ไหน มีค่าระหว่าง **-1 ถึง 1**:
# - **ใกล้ +1** → สัมพันธ์ไปทางเดียวกัน (ตัวหนึ่งเพิ่ม อีกตัวก็เพิ่มตาม)
# - **ใกล้ -1** → สัมพันธ์ตรงข้ามกัน (ตัวหนึ่งเพิ่ม อีกตัวลด)
# - **ใกล้ 0** → ไม่มีความสัมพันธ์เชิงเส้นชัดเจน
#
# `.corr()` ของ pandas คำนวณ correlation ระหว่างทุกคู่คอลัมน์ตัวเลข แล้ว `sns.heatmap()` ทำให้เห็นภาพรวมทั้งหมดในตารางเดียว

# %%
numeric_cols = ["temperature_c", "humidity_pct", "rainfall_mm", "wind_speed_kmh", "pressure_hpa"]
correlation_matrix = data[numeric_cols].corr()
print(correlation_matrix.round(2))

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", center=0, vmin=-1, vmax=1)
plt.title("Correlation Heatmap ระหว่างตัวแปรสภาพอากาศ")
plt.tight_layout()
plt.show()

# %% [markdown]
# **อ่าน Heatmap อย่างไร:**
# - `annot=True` → แสดงตัวเลขค่า correlation ในแต่ละช่อง
# - สีแดง (ใกล้ +1) → สัมพันธ์ไปทางเดียวกัน, สีน้ำเงิน (ใกล้ -1) → สัมพันธ์ตรงข้ามกัน
# - แนวทแยงมุม (จากซ้ายบนไปขวาล่าง) จะเป็น 1.0 เสมอ (ตัวแปรสัมพันธ์กับตัวมันเองสมบูรณ์แบบ)
#
# **🔍 สังเกต:** ลองดูว่า `temperature_c` กับ `humidity_pct` มีค่า correlation เท่าไหร่ และมีทิศทางไหน (บวก/ลบ) — ในข้อมูลภูมิอากาศจริง อุณหภูมิกับความชื้นมักมีความสัมพันธ์กันในระดับหนึ่งแต่ไม่สมบูรณ์แบบ
#
# **⚠️ ข้อควรระวังสำคัญ:** Correlation บอกแค่ความสัมพันธ์เชิงเส้น **ไม่ได้บอกว่าตัวแปรหนึ่ง "เป็นเหตุ" ของอีกตัวแปร** (correlation ≠ causation) — ต้องระมัดระวังการตีความเสมอ

# %% [markdown]
# ---
# ## 10. Pairplot — ดูความสัมพันธ์ทุกคู่ตัวแปรพร้อมกัน
#
# `sns.pairplot()` สร้าง scatter plot ของ**ทุกคู่ตัวแปร**ที่เลือก พร้อมฮิสโตแกรมในแนวทแยง — เป็นวิธีสำรวจข้อมูลเบื้องต้น (EDA) ที่ครอบคลุมและรวดเร็วที่สุด

# %%
numeric_cols = ["temperature_c", "humidity_pct", "rainfall_mm", "wind_speed_kmh", "pressure_hpa"]

sns.pairplot(data[numeric_cols])
plt.suptitle("Pairplot ของตัวแปรสภาพอากาศทั้งหมด", y=1.02)
plt.show()

# %% [markdown]
# **อ่าน Pairplot อย่างไร:**
# - **แนวทแยงมุม** → ฮิสโตแกรมของตัวแปรนั้นๆ (การกระจายตัวของตัวมันเอง)
# - **ช่องอื่นๆ** → scatter plot ระหว่างตัวแปรในแถวกับคอลัมน์นั้น (เห็นความสัมพันธ์แบบเดียวกับ heatmap แต่เป็นภาพจุดจริง ไม่ใช่แค่ตัวเลขสรุป)

# %% [markdown]
# ### 10.1 Pairplot พร้อมแยกสีตามกลุ่ม (`hue`)

# %%
sample_with_region = data[numeric_cols + ["region"]].sample(500, random_state=42)

sns.pairplot(sample_with_region, hue="region", plot_kws={"alpha": 0.5})
plt.suptitle("Pairplot แยกสีตาม Region", y=1.02)
plt.show()

# %% [markdown]
# **🔍 สังเกต:** การแยกสีตาม `region` ช่วยให้เห็นว่าความสัมพันธ์ระหว่างตัวแปรอาจ**แตกต่างกันในแต่ละกลุ่ม** — เป็นเทคนิคที่มีประโยชน์มากในขั้นตอนสำรวจข้อมูลก่อนตัดสินใจว่าจะสร้างโมเดลแยกตามกลุ่มหรือไม่
#
# > ⚠️ **ข้อควรระวัง:** `pairplot()` คำนวณกราฟจำนวนมาก (N² กราฟ เมื่อ N คือจำนวนคอลัมน์) จึง**ช้าและกินทรัพยากรมาก**ถ้าข้อมูลมีหลายคอลัมน์หรือหลายแถว ควร `.sample()` ข้อมูลก่อนเสมอเมื่อข้อมูลมีขนาดใหญ่ (เหมือนตัวอย่างที่ทำไว้ข้างบน)

# %% [markdown]
# ---
# # ส่วนที่ 3: Visualization for Insight
#
# จนถึงตอนนี้รู้จักกราฟหลายชนิดแล้ว — หัวข้อนี้จะเน้น **"การตัดสินใจ"** ว่าควรใช้กราฟแบบไหนกับข้อมูลแบบไหน และจะทำให้กราฟ "สื่อ insight" ได้จริง ไม่ใช่แค่ "วาดได้"
#
# ## 11. เลือก Chart Type ให้เหมาะกับข้อมูล
#
# | คำถามที่อยากตอบ | Chart Type ที่เหมาะ | ตัวอย่าง |
# |---|---|---|
# | แนวโน้มตามเวลาเปลี่ยนแปลงอย่างไร? | **Line Chart** | อุณหภูมิรายวันของเมืองหนึ่งตลอด 90 วัน |
# | ตัวแปร 2 ตัวสัมพันธ์กันไหม? | **Scatter Plot** | ความชื้น vs ปริมาณฝน |
# | เปรียบเทียบค่าระหว่างกลุ่ม (หมวดหมู่)? | **Bar Chart** | อุณหภูมิเฉลี่ยของแต่ละภูมิภาค |
# | ข้อมูลตัวเลขกระจายตัวอย่างไร? | **Histogram** | การกระจายตัวของอุณหภูมิทั้งหมด |
# | เปรียบเทียบการกระจายตัวระหว่างกลุ่ม + หา outliers? | **Boxplot** | อุณหภูมิแยกตามภูมิภาค |
# | ความสัมพันธ์ระหว่างตัวแปรหลายคู่พร้อมกัน? | **Heatmap / Pairplot** | correlation ระหว่างตัวแปรสภาพอากาศทั้งหมด |
# | สัดส่วนของส่วนประกอบทั้งหมด? | **Pie Chart** (ใช้น้อยกว่าที่คิด — ดูหัวข้อถัดไป) | สัดส่วนจำนวนวันที่ฝนตก/ไม่ตก |
#
# ### 11.1 กรณีศึกษา: เลือกผิดประเภทแล้วสื่อความหมายผิด
#
# ลองดูตัวอย่างที่ใช้กราฟผิดประเภทกับคำถามที่ต้องการตอบ

# %%
# ❌ ตัวอย่างไม่ดี: ใช้ Line Chart กับข้อมูลที่ไม่มีลำดับเวลาที่ต่อเนื่องกัน (เมืองเรียงตามตัวอักษร ไม่ใช่ตามเวลา)
avg_by_city = data.groupby("city")["temperature_c"].mean().sort_index()   # เรียงตามชื่อ A-Z

plt.figure(figsize=(12, 5))
plt.plot(avg_by_city.index, avg_by_city.values, marker="o")
plt.title("อุณหภูมิเฉลี่ยแต่ละเมือง (ใช้ Line Chart -- ตัวอย่างที่ไม่เหมาะ)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ปัญหา: เส้นเชื่อมระหว่างจุดบอกเป็นนัยว่ามี 'ความต่อเนื่อง' ระหว่างเมือง (เช่น เหมือนบอกว่า Auckland 'ไหลต่อ' ไปเป็น Bangkok) ซึ่งไม่มีความหมายอะไรเลย เพราะลำดับเมืองเรียงตามตัวอักษร ไม่ใช่ปริมาณที่ต่อเนื่องกันจริง

# %%
# ✅ ตัวอย่างที่ดีกว่า: ใช้ Bar Chart กับข้อมูลเชิงหมวดหมู่ (ไม่มีเส้นเชื่อมที่บอกความต่อเนื่องผิดๆ)
avg_by_city_sorted = data.groupby("city")["temperature_c"].mean().sort_values(ascending=False)

plt.figure(figsize=(12, 5))
plt.bar(avg_by_city_sorted.index, avg_by_city_sorted.values, color="steelblue")
plt.title("อุณหภูมิเฉลี่ยแต่ละเมือง เรียงจากร้อนสุดไปเย็นสุด")
plt.ylabel("อุณหภูมิเฉลี่ย (°C)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ดีขึ้น: Bar Chart ไม่บอกเป็นนัยถึงความต่อเนื่อง และการเรียงจากมากไปน้อย ช่วยให้เห็นการเปรียบเทียบระหว่างเมืองได้ทันทีโดยไม่ต้องไล่หาด้วยตา

# %% [markdown]
# ### 11.2 กรณีศึกษา: Pie Chart ใช้ยากกว่าที่คิด
#
# Pie Chart เป็นที่นิยมแต่จริงๆ**มนุษย์เปรียบเทียบมุม/พื้นที่ได้ไม่แม่นยำเท่าเปรียบเทียบความสูงของแท่ง** — ส่วนใหญ่ Bar Chart สื่อสารได้ดีกว่า โดยเฉพาะเมื่อมีหลายหมวดหมู่

# %%
rain_level_counts = pd.cut(
    data["rainfall_mm"], bins=[-0.1, 0, 5, 15, 100],
    labels=["ไม่มีฝน", "ฝนน้อย", "ฝนปานกลาง", "ฝนมาก"]
).value_counts()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].pie(rain_level_counts.values, labels=rain_level_counts.index, autopct="%1.1f%%")
axes[0].set_title("Pie Chart: สัดส่วนระดับฝนตก")

axes[1].bar(rain_level_counts.index, rain_level_counts.values, color="steelblue")
axes[1].set_title("Bar Chart: จำนวนวันแต่ละระดับฝนตก")
axes[1].set_ylabel("จำนวนวัน")

plt.tight_layout()
plt.show()

# %% [markdown]
# ลองเทียบ: Bar Chart (ขวา) อ่านค่าและเปรียบเทียบระหว่างกลุ่มได้แม่นยำกว่า Pie Chart (ซ้าย) อย่างเห็นได้ชัด โดยเฉพาะเมื่อสัดส่วนของบางกลุ่มใกล้เคียงกัน

# %% [markdown]
# ---

# %% [markdown]
# ## 12. ตั้งชื่อกราฟให้สื่อความหมาย
#
# ชื่อกราฟที่ดีไม่ใช่แค่ "บอกว่ากราฟนี้คือข้อมูลอะไร" แต่ควร **"บอก insight ที่อยากให้คนดูเห็น"** ด้วย — เปรียบเทียบ 2 แบบ
#
# | ชื่อกราฟแบบทั่วไป (Descriptive) | ชื่อกราฟแบบสื่อ Insight (Insight-driven) |
# |---|---|
# | "อุณหภูมิเฉลี่ยแยกตามภูมิภาค" | "เอเชียและแอฟริการ้อนกว่ายุโรปเฉลี่ย 15 องศา" |
# | "ความสัมพันธ์ระหว่างความชื้นและฝน" | "ความชื้นสูงกว่า 80% มักมาพร้อมฝนตกหนัก" |
# | "อุณหภูมิรายวันที่กรุงเทพฯ" | "กรุงเทพฯร้อนขึ้นต่อเนื่องตลอดเดือนมีนาคม" |
#
# **หลักการ:** ชื่อแบบ Descriptive บอกแค่ "ตัวแปรอะไรอยู่ในกราฟ" ส่วนชื่อแบบ Insight-driven บอก **"สิ่งที่ค้นพบ"** จากกราฟนั้น — ผู้อ่านที่เร่งรีบอาจดูแค่ชื่อกราฟก็ได้ข้อมูลสำคัญไปแล้ว โดยไม่ต้องตีความกราฟเอง

# %% [markdown]
# ### 12.1 ตัวอย่าง: เปลี่ยนชื่อกราฟจาก Descriptive เป็น Insight-driven

# %%
avg_temp_by_region = data.groupby("region")["temperature_c"].mean().sort_values(ascending=False)

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# กราฟซ้าย: ชื่อแบบทั่วไป
axes[0].bar(avg_temp_by_region.index, avg_temp_by_region.values, color="lightgray")
axes[0].set_title("อุณหภูมิเฉลี่ยแยกตามภูมิภาค", fontsize=12)
axes[0].set_ylabel("อุณหภูมิเฉลี่ย (°C)")
axes[0].tick_params(axis="x", rotation=20)

# กราฟขวา: ชื่อแบบสื่อ insight + เน้นสีที่ประเด็นสำคัญ
colors = ["firebrick" if r in ["Asia", "Africa"] else "lightgray" for r in avg_temp_by_region.index]
diff = avg_temp_by_region["Asia"] - avg_temp_by_region["Europe"]
axes[1].bar(avg_temp_by_region.index, avg_temp_by_region.values, color=colors)
axes[1].set_title(f"เอเชียร้อนกว่ายุโรปเฉลี่ย {diff:.1f}°C", fontsize=12, fontweight="bold")
axes[1].set_ylabel("อุณหภูมิเฉลี่ย (°C)")
axes[1].tick_params(axis="x", rotation=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# **🔍 สังเกต:** กราฟขวาทำ 2 อย่างที่กราฟซ้ายไม่ได้ทำ:
# 1. **ชื่อกราฟบอก insight ตรงๆ** (ไม่ต้องตีความเอง)
# 2. **ใช้สีเน้น (highlight)** เฉพาะแท่งที่เกี่ยวข้องกับ insight นั้น ส่วนแท่งอื่นใช้สีเรียบเพื่อไม่ให้แย่งความสนใจ

# %% [markdown]
# ### 12.2 หลักการตั้งชื่อกราฟที่ดี
#
# - **เจาะจง** — ใส่ตัวเลขจริงถ้าเป็นไปได้ (เช่น "ร้อนกว่า 15°C" ดีกว่า "ร้อนกว่ามาก")
# - **สั้นกระชับ** — 1 บรรทัด อ่านจบในไม่กี่วินาที
# - **ตรงประเด็น** — ตอบคำถามที่กราฟนี้ถูกสร้างมาเพื่อตอบ ไม่ใช่บอกแค่ "นี่คือกราฟอะไร"
# - **ไม่กล่าวเกินจริง** — insight ต้องสอดคล้องกับข้อมูลจริง ไม่ใช่บีบให้ข้อมูลสนับสนุนสิ่งที่อยากพูด

# %% [markdown]
# ---
# ## 13. Storytelling เบื้องต้นด้วยข้อมูล
#
# **Data Storytelling** คือการนำเสนอข้อมูลเป็น "เรื่องราว" ที่มีลำดับ ชัดเจน และโน้มน้าวใจ — ไม่ใช่แค่โชว์กราฟสวยๆ แต่นำกราฟหลายอันมาเรียงเป็นลำดับเพื่อ "เล่าเรื่อง" ให้ผู้ฟังเข้าใจประเด็นทีละขั้น
#
# ### โครงสร้าง Storytelling เบื้องต้น (3 ขั้น)
#
# 1. **Context (ตั้งคำถาม)** — เริ่มด้วยคำถามหรือบริบทที่ผู้ฟังสนใจ
# 2. **Evidence (แสดงหลักฐาน)** — ใช้กราฟค่อยๆ คลี่คลายคำถามนั้นทีละขั้น
# 3. **Conclusion (สรุปและเสนอแนะ)** — สรุป insight และ (ถ้าเหมาะสม) เสนอแนะสิ่งที่ควรทำต่อ
#
# ### ตัวอย่าง Storytelling แบบสมบูรณ์: "เมืองไหนในเอเชียที่ฝนตกบ่อยที่สุด และเกี่ยวข้องกับความชื้นอย่างไร?"
#
# **ขั้นที่ 1 — Context:** ตั้งคำถามให้ชัดก่อนเริ่มดูข้อมูล

# %%
asian_data = data[data["region"] == "Asia"]
print(f"กำลังวิเคราะห์ข้อมูล {len(asian_data)} แถว จาก {asian_data['city'].nunique()} เมืองในเอเชีย")
print("คำถาม: เมืองไหนฝนตกบ่อยที่สุด และความชื้นมีความสัมพันธ์กับฝนแค่ไหน?")

# %% [markdown]
# **ขั้นที่ 2 — Evidence (กราฟที่ 1):** เริ่มจากภาพรวมกว้างๆ

# %%
rainy_days_by_city = (asian_data[asian_data["rainfall_mm"] > 5]
                       .groupby("city").size()
                       .sort_values(ascending=False))

# %%
rainy_days_by_city

# %%
plt.figure(figsize=(10, 5))
colors = ["firebrick" if i == 0 else "lightgray" for i in range(len(rainy_days_by_city))]
plt.bar(rainy_days_by_city.index, rainy_days_by_city.values, color=colors)
plt.title(f"{rainy_days_by_city.index[0]} มีวันฝนตกมากที่สุดในเอเชีย ({rainy_days_by_city.iloc[0]} วัน จาก 90 วัน)")
plt.ylabel("จำนวนวันที่ฝนตก (>5mm)")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# **ขั้นที่ 2 — Evidence (กราฟที่ 2):** เจาะลึกเมืองที่น่าสนใจที่สุดจากกราฟแรก

# %%
top_city = rainy_days_by_city.index[0]
top_city_data = asian_data[asian_data["city"] == top_city]

plt.figure(figsize=(8, 6))
plt.scatter(top_city_data["humidity_pct"], top_city_data["rainfall_mm"], alpha=0.5, color="steelblue")
correlation = top_city_data["humidity_pct"].corr(top_city_data["rainfall_mm"])
plt.title(f"{top_city}: ความชื้นและฝนมีความสัมพันธ์กัน (correlation = {correlation:.2f})")
plt.xlabel("ความชื้น (%)")
plt.ylabel("ปริมาณฝน (mm)")
plt.tight_layout()
plt.show()

# %% [markdown]
# **ขั้นที่ 3 — Conclusion:** สรุปสิ่งที่ค้นพบจากทั้ง 2 กราฟ

# %%
print(f"สรุปผลการวิเคราะห์:")
print(f"1. {top_city} เป็นเมืองที่ฝนตกบ่อยที่สุดในเอเชียจากข้อมูลนี้ ({rainy_days_by_city.iloc[0]} วัน จาก 90 วัน)")
print(f"2. ความชื้นและปริมาณฝนใน {top_city} มี correlation = {correlation:.2f} "
      f"({'สัมพันธ์ไปทางเดียวกันระดับปานกลางถึงสูง' if correlation > 0.3 else 'สัมพันธ์กันค่อนข้างน้อย'})")
print(f"3. ข้อเสนอแนะ: หากต้องวางแผนกิจกรรมกลางแจ้งใน {top_city} ควรติดตามค่าความชื้นเป็นตัวบ่งชี้เบื้องต้นของโอกาสฝนตก")

# %% [markdown]
# ### 13.1 ข้อคิดสำคัญเกี่ยวกับ Storytelling
#
# - **เรียงกราฟจากกว้างไปแคบ (Overview → Detail)** ช่วยให้ผู้ฟังตามเรื่องราวได้ง่ายกว่าโชว์กราฟละเอียดทันที
# - **ทุกกราฟควรมีหน้าที่ในเรื่องราว** — ถ้ากราฟไม่ได้ช่วยตอบคำถามหรือนำไปสู่ข้อสรุป ควรตัดออก (Less is more)
# - **Conclusion ต้องเชื่อมโยงกับ Context ที่ตั้งไว้ตอนแรก** — กลับไปตอบคำถามเริ่มต้นเสมอ
# - **ความซื่อตรงต่อข้อมูลสำคัญที่สุด** — Storytelling ไม่ใช่การ "เลือกเฉพาะข้อมูลที่สนับสนุนเรื่องที่อยากเล่า" แต่คือการนำเสนอสิ่งที่ข้อมูลบอกจริงๆให้เข้าใจง่ายที่สุด

# %% [markdown]
# ---
# ## 🧪 แบบฝึกหัดท้ายคาบ
#
# > ลองทำเองในเซลล์ที่เตรียมไว้ด้านล่างแต่ละข้อ ไม่มีเฉลยให้ — ถ้าไม่แน่ใจให้ลองรันดูผลลัพธ์ หรือถามอาจารย์/เพื่อนได้เลย ใช้ตัวแปร `data` ที่ merge และทำความสะอาดแล้วตลอดทั้งไฟล์นี้
#
# ### ข้อ 1: matplotlib พื้นฐาน
# สร้าง 4 กราฟแยกกัน (ใส่ title, xlabel, ylabel ให้ครบทุกกราฟ):
# 1. Line chart: อุณหภูมิรายวันของเมือง `"Sydney"`
# 2. Scatter plot: `pressure_hpa` กับ `wind_speed_kmh`
# 3. Bar chart: ปริมาณฝนเฉลี่ยแยกตาม `region`
# 4. Histogram: การกระจายตัวของ `wind_speed_kmh`

# %%
# เขียนคำตอบข้อ 1 ที่นี่

# 1. Line chart: อุณหภูมิรายวันของเมือง "Sydney"
sydney_data = data[data["city"] == "Sydney"].sort_values("date")
plt.figure(figsize=(10, 5))
plt.plot(sydney_data["date"], sydney_data["temperature_c"], color="purple")
plt.title("อุณหภูมิรายวันของเมือง Sydney")
plt.xlabel("วันที่")
plt.ylabel("อุณหภูมิ (°C)")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# 2. Scatter plot: pressure_hpa กับ wind_speed_kmh
plt.figure(figsize=(10, 5))
plt.scatter(data["pressure_hpa"], data["wind_speed_kmh"], alpha=0.5, color="darkgreen")
plt.title("ความสัมพันธ์ระหว่างความกดอากาศและลม")
plt.xlabel("ความกดอากาศ (hPa)")
plt.ylabel("ความเร็วลม (km/h)")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# 3. Bar chart: ปริมาณฝนเฉลี่ยแยกตาม region
avg_rainfall_by_region = data.groupby("region")["rainfall_mm"].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 5))
plt.bar(avg_rainfall_by_region.index, avg_rainfall_by_region.values, color="steelblue")
plt.title("ปริมาณฝนเฉลี่ยแยกตามภูมิภาค")
plt.xlabel("ภูมิภาค")
plt.ylabel("ปริมาณฝนเฉลี่ย (mm)")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# 4. Histogram: การกระจายตัวของ wind_speed_kmh
plt.figure(figsize=(10, 5))
plt.hist(data["wind_speed_kmh"], bins=20, color="orange", edgecolor="black")
plt.title("การกระจายตัวของความเร็วลม")
plt.xlabel("ความเร็วลม (km/h)")
plt.ylabel("ความถี่")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ข้อ 2: Subplot
# สร้าง subplot ขนาด 2x2 ที่รวม 4 กราฟจากข้อ 1 ไว้ในภาพเดียว พร้อม `plt.suptitle()` ตั้งชื่อรวมให้ทั้งภาพ

# %%
# เขียนคำตอบข้อ 2 ที่นี่
import matplotlib.pyplot as plt

# สร้าง Figure และกำหนดขนาดภาพรวม (กว้าง 14, สูง 10)
plt.figure(figsize=(14, 10))

# ตั้งชื่อภาพรวมทั้งหมด (Super Title)
plt.suptitle("สรุปข้อมูลสภาพอากาศ (Weather Data Summary)", fontsize=16, fontweight="bold")

# --------------------------------------------------
# ตำแหน่งที่ 1: มุมซ้ายบน (2 แถว, 2 คอลัมน์, ภาพที่ 1)
# --------------------------------------------------
plt.subplot(2, 2, 1)
sydney_data = data[data["city"] == "Sydney"].sort_values("date")
plt.plot(sydney_data["date"], sydney_data["temperature_c"], color="purple")
plt.title("อุณหภูมิรายวันของเมือง Sydney")
plt.xlabel("วันที่")
plt.ylabel("อุณหภูมิ (°C)")
plt.grid(alpha=0.3)

# --------------------------------------------------
# ตำแหน่งที่ 2: มุมขวาบน (2 แถว, 2 คอลัมน์, ภาพที่ 2)
# --------------------------------------------------
plt.subplot(2, 2, 2)
plt.scatter(data["pressure_hpa"], data["wind_speed_kmh"], alpha=0.5, color="darkgreen")
plt.title("ความสัมพันธ์ระหว่างความกดอากาศและลม")
plt.xlabel("ความกดอากาศ (hPa)")
plt.ylabel("ความเร็วลม (km/h)")
plt.grid(alpha=0.3)

# --------------------------------------------------
# ตำแหน่งที่ 3: มุมซ้ายล่าง (2 แถว, 2 คอลัมน์, ภาพที่ 3)
# --------------------------------------------------
plt.subplot(2, 2, 3)
avg_rainfall_by_region = data.groupby("region")["rainfall_mm"].mean().sort_values(ascending=False)
plt.bar(avg_rainfall_by_region.index, avg_rainfall_by_region.values, color="steelblue")
plt.title("ปริมาณฝนเฉลี่ยแยกตามภูมิภาค")
plt.xlabel("ภูมิภาค")
plt.ylabel("ปริมาณฝนเฉลี่ย (mm)")
plt.xticks(rotation=30)

# --------------------------------------------------
# ตำแหน่งที่ 4: มุมขวาล่าง (2 แถว, 2 คอลัมน์, ภาพที่ 4)
# --------------------------------------------------
plt.subplot(2, 2, 4)
plt.hist(data["wind_speed_kmh"], bins=20, color="orange", edgecolor="black")
plt.title("การกระจายตัวของความเร็วลม")
plt.xlabel("ความเร็วลม (km/h)")
plt.ylabel("ความถี่")
plt.grid(alpha=0.3)

# จัดระยะห่างระหว่างกราฟย่อยไม่ให้ข้อความทับกัน
plt.tight_layout()

# แสดงผลภาพ
plt.show()

# %% [markdown]
# ### ข้อ 3: seaborn
# 1. สร้าง boxplot เปรียบเทียบ `rainfall_mm` แยกตาม `region` พร้อม `hue` แยกตาม `is_weekend`
# 2. สร้าง correlation heatmap ระหว่าง `temperature_c`, `humidity_pct`, `rainfall_mm`, `population_millions`, `avg_gdp_growth_pct` (คอลัมน์ที่ได้มาจากการ merge ตอนต้นไฟล์)
# 3. ตอบในคอมเมนต์: มีคู่ตัวแปรไหนที่ correlation สูงเกินคาด หรือต่ำกว่าที่คาดไว้ไหม?

# %%
# เขียนคำตอบข้อ 3 ที่นี่
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# ----------------------------------------------------------------------
# 0. เตรียมคอลัมน์ is_weekend (ป้องกัน KeyError กรณีที่ใน data ยังไม่มี)
# ----------------------------------------------------------------------
data["date"] = pd.to_datetime(data["date"])
data["is_weekend"] = data["date"].dt.dayofweek >= 5  # 5=เสาร์, 6=อาทิตย์

sns.set_theme(style="whitegrid")

# ----------------------------------------------------------------------
# 1. Boxplot เปรียบเทียบ rainfall_mm แยกตาม region และ hue ด้วย is_weekend
# ----------------------------------------------------------------------
plt.figure(figsize=(10, 6))

# เขียนรวมไว้ในบรรทัดเดียวเพื่อป้องกัน SyntaxError ตอน Copy
sns.boxplot(
    data=data, x="region", y="rainfall_mm", hue="is_weekend", palette="Set2"
)

plt.title("การเปรียบเทียบปริมาณฝน (rainfall_mm) แยกตามภูมิภาคและวันหยุด")
plt.xlabel("ภูมิภาค (Region)")
plt.ylabel("ปริมาณฝน (mm)")
plt.tight_layout()
plt.show()


# ----------------------------------------------------------------------
# 2. Correlation Heatmap
# ----------------------------------------------------------------------
cols_to_corr = [
    "temperature_c",
    "humidity_pct",
    "rainfall_mm",
    "population_millions",
    "avg_gdp_growth_pct",
]

corr_matrix = data[cols_to_corr].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    vmin=-1,
    vmax=1,
    linewidths=0.5,
)
plt.title("Correlation Heatmap ระหว่างปัจจัยสภาพอากาศและเศรษฐกิจ/ประชากร")
plt.tight_layout()
plt.show()

# ----------------------------------------------------------------------
# 3. คอมเมนต์วิเคราะห์
# ----------------------------------------------------------------------
"""
[คำตอบวิเคราะห์ Correlation]:

1. คู่ตัวแปรที่มี Correlation ต่ำกว่าที่คาดไว้:
   - สภาพอากาศ (temperature_c, humidity_pct, rainfall_mm) กับ ปัจจัยทางเศรษฐกิจ/ประชากร (population_millions, avg_gdp_growth_pct)
   - เหตุผล: ค่า Correlation เข้าใกล้ 0.00 เนื่องจากสภาพอากาศรายวัน ไม่มีความสัมพันธ์เชิงสถิติโดยตรงกับประชากรหรือ GDP เฉลี่ยในระยะยาว

2. คู่ตัวแปรที่ควรสังเกต:
   - หาก humidity_pct กับ rainfall_mm มีค่าต่ำกว่า 0.3 ถือว่าต่ำกว่าที่คาด เพราะวันฝนตกควรมีความชื้นสัมพัทธ์สูง
   - หาก temperature_c กับ humidity_pct ติดลบ แสดงว่าเมื่ออุณหภูมิสูงขึ้น ความชื้นสัมพัทธ์จะลดลงซึ่งสอดคล้องกับธรรมชาติ
"""
# Out:
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3603 (\N{THAI CHARACTER NO NEN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3613 (\N{THAI CHARACTER FO FA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3610 (\N{THAI CHARACTER BO BAIMAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3607 (\N{THAI CHARACTER THO THAHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3605 (\N{THAI CHARACTER TO TAO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3627 (\N{THAI CHARACTER HO HIP}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3640 (\N{THAI CHARACTER SARA U}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:27: UserWarning: Glyph 3604 (\N{THAI CHARACTER DO DEK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3603 (\N{THAI CHARACTER NO NEN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3613 (\N{THAI CHARACTER FO FA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3610 (\N{THAI CHARACTER BO BAIMAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3607 (\N{THAI CHARACTER THO THAHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3605 (\N{THAI CHARACTER TO TAO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3627 (\N{THAI CHARACTER HO HIP}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3640 (\N{THAI CHARACTER SARA U}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3604 (\N{THAI CHARACTER DO DEK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3627 (\N{THAI CHARACTER HO HIP}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3614 (\N{THAI CHARACTER PHO PHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3624 (\N{THAI CHARACTER SO SALA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3625 (\N{THAI CHARACTER SO RUSI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3600 (\N{THAI CHARACTER THO THAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/40272201.py:55: UserWarning: Glyph 3594 (\N{THAI CHARACTER CHO CHANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3627 (\N{THAI CHARACTER HO HIP}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3614 (\N{THAI CHARACTER PHO PHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3624 (\N{THAI CHARACTER SO SALA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3625 (\N{THAI CHARACTER SO RUSI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3600 (\N{THAI CHARACTER THO THAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3594 (\N{THAI CHARACTER CHO CHANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# '\n[คำตอบวิเคราะห์ Correlation]:\n\n1. คู่ตัวแปรที่มี Correlation ต่ำกว่าที่คาดไว้:\n   - สภาพอากาศ (temperature_c, humidity_pct, rainfall_mm) กับ ปัจจัยทางเศรษฐกิจ/ประชากร (population_millions, avg_gdp_growth_pct)\n   - เหตุผล: ค่า Correlation เข้าใกล้ 0.00 เนื่องจากสภาพอากาศรายวัน ไม่มีความสัมพันธ์เชิงสถิติโดยตรงกับประชากรหรือ GDP เฉลี่ยในระยะยาว\n\n2. คู่ตัวแปรที่ควรสังเกต:\n   - หาก humidity_pct กับ rainfall_mm มีค่าต่ำกว่า 0.3 ถือว่าต่ำกว่าที่คาด เพราะวันฝนตกควรมีความชื้นสัมพัทธ์สูง\n   - หาก temperature_c กับ humidity_pct ติดลบ แสดงว่าเมื่ออุณหภูมิสูงขึ้น ความชื้นสัมพัทธ์จะลดลงซึ่งสอดคล้องกับธรรมชาติ\n'

# %% [markdown]
# ### ข้อ 4: เลือก Chart Type ให้เหมาะสม
# สำหรับ 3 สถานการณ์นี้ จงเลือกและสร้างกราฟที่เหมาะสมที่สุด (พร้อมเหตุผลในคอมเมนต์ว่าทำไมเลือกแบบนี้):
# 1. อยากดูว่า `population_millions` ของเมืองมีผลต่อ `temperature_c` เฉลี่ยหรือไม่
# 2. อยากเปรียบเทียบจำนวนเมืองในแต่ละ `region`
# 3. อยากดูว่าอุณหภูมิของเมือง `"Moscow"` เปลี่ยนแปลงอย่างไรในช่วง 90 วัน

# %%
# เขียนคำตอบข้อ 4 ที่นี่
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# ==============================================================================
# 1. ดูว่า population_millions ของเมืองมีผลต่อ temperature_c เฉลี่ยหรือไม่
# Chart Type: Scatter Plot (กราฟการกระจาย)
# ==============================================================================
# หาค่าอุณหภูมิเฉลี่ยและประชากรของแต่ละเมืองก่อน
city_summary = (
    data.groupby("city")
    .agg({"population_millions": "first", "temperature_c": "mean"})
    .reset_index()
)

plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=city_summary,
    x="population_millions",
    y="temperature_c",
    color="crimson",
    s=80,
)
plt.title("ความสัมพันธ์ระหว่างจำนวนประชากรและอุณหภูมิเฉลี่ยของเมือง")
plt.xlabel("จำนวนประชากร (ล้านคน)")
plt.ylabel("อุณหภูมิเฉลี่ย (°C)")
plt.tight_layout()
plt.show()

"""
[เหตุผลที่เลือก Scatter Plot]:
- เหมาะสำหรับการหาความสัมพันธ์ (Correlation/Relationship) ระหว่างตัวแปรเชิงตัวเลข (Numerical Variables) 2 ตัว
- ช่วยให้เห็นทิศทางของข้อมูลได้ชัดเจนว่า เมื่อจำนวนประชากรเพิ่มขึ้น อุณหภูมิเฉลี่ยมีแนวโน้มสูงขึ้น ลดลง หรือไม่มีความสัมพันธ์กันเลย
"""


# ==============================================================================
# 2. เปรียบเทียบจำนวนเมืองในแต่ละ region
# Chart Type: Bar Chart / Count Plot (กราฟแท่ง)
# ==============================================================================
# นับจำนวนเมืองแบบไม่ซ้ำ (Unique Cities) ในแต่ละ Region
cities_per_region = (
    data.groupby("region")["city"].nunique().reset_index(name="city_count")
)

plt.figure(figsize=(8, 5))
sns.barplot(
    data=cities_per_region,
    x="region",
    y="city_count",
    hue="region",
    palette="viridis",
    legend=False,
)
plt.title("เปรียบเทียบจำนวนเมืองในแต่ละภูมิภาค")
plt.xlabel("ภูมิภาค (Region)")
plt.ylabel("จำนวนเมือง")
plt.tight_layout()
plt.show()

"""
[เหตุผลที่เลือก Bar Chart]:
- เหมาะสำหรับการเปรียบเทียบเชิงปริมาณระหว่างกลุ่มข้อมูลที่เป็นหมวดหมู่ (Categorical Data)
- ความสูงของแท่งกราฟช่วยให้เปรียบเทียบความแตกต่างระหว่างภูมิภาคต่าง ๆ ได้ง่าย สแกนสายตาแล้วเข้าใจทันที
"""


# ==============================================================================
# 3. ดูว่าอุณหภูมิของเมือง "Moscow" เปลี่ยนแปลงอย่างไรในช่วง 90 วัน
# Chart Type: Line Chart (กราฟเส้น)
# ==============================================================================
moscow_data = (
    data[data["city"] == "Moscow"]
    .sort_values("date")
    .head(90)  # กรองเฉพาะข้อมูล 90 วันแรก
)

plt.figure(figsize=(10, 5))
plt.plot(
    moscow_data["date"],
    moscow_data["temperature_c"],
    color="dodgerblue",
    linewidth=2,
)
plt.title("การเปลี่ยนแปลงอุณหภูมิของเมือง Moscow ในช่วง 90 วัน")
plt.xlabel("วันที่")
plt.ylabel("อุณหภูมิ (°C)")
plt.xticks(rotation=30)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

"""
[เหตุผลที่เลือก Line Chart]:
- เหมาะอย่างยิ่งสำหรับข้อมูลอนุกรมเวลา (Time-Series Data) ที่มีความต่อเนื่องตามลำดับเวลา
- เส้นกราฟที่เชื่อมต่อกันช่วยให้เห็นแนวโน้ม (Trend) การเพิ่มขึ้น, ลดลง หรือความผันผวนของอุณหภูมิตามช่วงเวลาได้อย่างชัดเจน
"""
# Out:
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3635 (\N{THAI CHARACTER SARA AM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3594 (\N{THAI CHARACTER CHO CHANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3657 (\N{THAI CHARACTER MAI THO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3640 (\N{THAI CHARACTER SARA U}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3603 (\N{THAI CHARACTER NO NEN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3627 (\N{THAI CHARACTER HO HIP}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3593 (\N{THAI CHARACTER CHO CHING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3614 (\N{THAI CHARACTER PHO PHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3608 (\N{THAI CHARACTER THO THONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3660 (\N{THAI CHARACTER THANTHAKHAT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3586 (\N{THAI CHARACTER KHO KHAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:29: UserWarning: Glyph 3639 (\N{THAI CHARACTER SARA UEE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3640 (\N{THAI CHARACTER SARA U}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3603 (\N{THAI CHARACTER NO NEN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3627 (\N{THAI CHARACTER HO HIP}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3593 (\N{THAI CHARACTER CHO CHING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3614 (\N{THAI CHARACTER PHO PHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3608 (\N{THAI CHARACTER THO THONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3660 (\N{THAI CHARACTER THANTHAKHAT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3635 (\N{THAI CHARACTER SARA AM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3594 (\N{THAI CHARACTER CHO CHANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3586 (\N{THAI CHARACTER KHO KHAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3639 (\N{THAI CHARACTER SARA UEE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3657 (\N{THAI CHARACTER MAI THO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3635 (\N{THAI CHARACTER SARA AM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3639 (\N{THAI CHARACTER SARA UEE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3610 (\N{THAI CHARACTER BO BAIMAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3607 (\N{THAI CHARACTER THO THAHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3651 (\N{THAI CHARACTER SARA AI MAIMUAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3605 (\N{THAI CHARACTER TO TAO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:60: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3635 (\N{THAI CHARACTER SARA AM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3639 (\N{THAI CHARACTER SARA UEE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3610 (\N{THAI CHARACTER BO BAIMAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3607 (\N{THAI CHARACTER THO THAHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3651 (\N{THAI CHARACTER SARA AI MAIMUAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3605 (\N{THAI CHARACTER TO TAO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3607 (\N{THAI CHARACTER THO THAHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3640 (\N{THAI CHARACTER SARA U}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3603 (\N{THAI CHARACTER NO NEN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3627 (\N{THAI CHARACTER HO HIP}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3586 (\N{THAI CHARACTER KHO KHAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3639 (\N{THAI CHARACTER SARA UEE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3651 (\N{THAI CHARACTER SARA AI MAIMUAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/880406403.py:92: UserWarning: Glyph 3594 (\N{THAI CHARACTER CHO CHANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3640 (\N{THAI CHARACTER SARA U}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3603 (\N{THAI CHARACTER NO NEN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3627 (\N{THAI CHARACTER HO HIP}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3586 (\N{THAI CHARACTER KHO KHAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3594 (\N{THAI CHARACTER CHO CHANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# '\n[เหตุผลที่เลือก Line Chart]:\n- เหมาะอย่างยิ่งสำหรับข้อมูลอนุกรมเวลา (Time-Series Data) ที่มีความต่อเนื่องตามลำดับเวลา\n- เส้นกราฟที่เชื่อมต่อกันช่วยให้เห็นแนวโน้ม (Trend) การเพิ่มขึ้น, ลดลง หรือความผันผวนของอุณหภูมิตามช่วงเวลาได้อย่างชัดเจน\n'

# %% [markdown]
# ### ข้อ 5: ตั้งชื่อกราฟให้สื่อความหมาย
# 1. สร้างกราฟ bar chart เปรียบเทียบ `population_millions` เฉลี่ยของแต่ละ `region` (ใช้ `.drop_duplicates(subset="city")` ก่อน group เพื่อไม่นับประชากรซ้ำหลายครั้งต่อเมือง)
# 2. ตั้งชื่อกราฟ 2 แบบ: แบบ Descriptive ธรรมดา 1 ชื่อ และแบบ Insight-driven (มีตัวเลขประกอบ) อีก 1 ชื่อ
# 3. ใช้สีเน้น (highlight) เฉพาะ region ที่มีประชากรเฉลี่ยสูงสุด เหมือนตัวอย่างที่เรียนมา

# %%
# เขียนคำตอบข้อ 5 ที่นี่
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="white")

# ==============================================================================
# 1. เตรียมข้อมูล: ตัดข้อมูลเมืองซ้ำ แล้วหาประชากรเฉลี่ยแยกตาม Region
# ==============================================================================
unique_cities = data.drop_duplicates(subset="city")

avg_pop_by_region = (
    unique_cities.groupby("region")["population_millions"]
    .mean()
    .reset_index()
    .sort_values(by="population_millions", ascending=False)
)

# ดึงค่าภูมิภาคที่มีประชากรเฉลี่ยสูงสุด และค่าตัวเลขออกมา
max_row = avg_pop_by_region.iloc[0]
max_region = max_row["region"]
max_val = max_row["population_millions"]

# ==============================================================================
# 2. กำหนดชื่อกราฟทั้ง 2 รูปแบบ
# ==============================================================================
# แบบที่ 1: Descriptive Title (อธิบายเชิงบรรยายสั้นๆ)
title_descriptive = "ประชากรเฉลี่ยต่อเมืองแยกตามภูมิภาค"

# แบบที่ 2: Insight-driven Title (สรุปประเด็นสำคัญพร้อมตัวเลข)
title_insight = (
    f"{max_region} มีประชากรเฉลี่ยต่อเมืองสูงสุด ({max_val:.1f} ล้านคน)"
)

# ==============================================================================
# 3. สร้าง Bar Chart และทำ Highlight เฉพาะแถบที่สูงที่สุด
# ==============================================================================
# กำหนดโทนสี: สีส้มเน้นเฉพาะอันสูงสุด ส่วนอันอื่นใช้สีเทาอ่อน (Muted Gray)
colors = [
    "#E65100" if r == max_region else "#CFD8DC"
    for r in avg_pop_by_region["region"]
]

plt.figure(figsize=(9, 5.5))
bars = plt.bar(
    avg_pop_by_region["region"],
    avg_pop_by_region["population_millions"],
    color=colors,
    width=0.6,
)

# แสดงตัวเลขกำกับบนยอดแท่งกราฟ (Data Labels)
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2.0,
        height + (max_val * 0.02),  # เว้นระยะเหนือแท่งเล็กน้อย
        f"{height:.1f}M",
        ha="center",
        va="bottom",
        fontsize=10,
        fontweight="bold" if height == max_val else "normal",
    )

# ตั้งชื่อกราฟแบบผสม (หรือเลือกใช้แบบใดแบบหนึ่งตามต้องการ)
plt.title(
    f"Descriptive: {title_descriptive}\nInsight-driven: {title_insight}",
    fontsize=12,
    pad=15,
    fontweight="bold",
    loc="left",
)

plt.xlabel("ภูมิภาค (Region)", fontsize=11)
plt.ylabel("ประชากรเฉลี่ย (ล้านคน)", fontsize=11)
plt.ylim(0, max_val * 1.18)  # ขยายแกน Y เพื่อไม่ให้ตัวเลขหลุดขอบบน
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()


# ==============================================================================
# 4. สรุปชื่อกราฟทั้ง 2 แบบ (สำหรับนำไปเขียนตอบ)
# ==============================================================================
"""
[คำตอบการตั้งชื่อกราฟ]:

1. Descriptive Title (บอกว่ากราฟเกี่ยวกับอะไร):
   "ปริมาณประชากรเฉลี่ยต่อเมืองแยกตามภูมิภาค"

2. Insight-driven Title (บอกข้อสรุปหลักพร้อมตัวเลข):
   f"{max_region} ครองอันดับ 1 มีประชากรเฉลี่ยต่อเมืองสูงที่สุดอยู่ที่ {max_val:.1f} ล้านคน"
"""
# Out:
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3594 (\N{THAI CHARACTER CHO CHANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3593 (\N{THAI CHARACTER CHO CHING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3657 (\N{THAI CHARACTER MAI THO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3605 (\N{THAI CHARACTER TO TAO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3639 (\N{THAI CHARACTER SARA UEE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3640 (\N{THAI CHARACTER SARA U}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/1546125980.py:78: UserWarning: Glyph 3604 (\N{THAI CHARACTER DO DEK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3594 (\N{THAI CHARACTER CHO CHANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3593 (\N{THAI CHARACTER CHO CHING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3657 (\N{THAI CHARACTER MAI THO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3605 (\N{THAI CHARACTER TO TAO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3639 (\N{THAI CHARACTER SARA UEE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3640 (\N{THAI CHARACTER SARA U}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3604 (\N{THAI CHARACTER DO DEK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# '\n[คำตอบการตั้งชื่อกราฟ]:\n\n1. Descriptive Title (บอกว่ากราฟเกี่ยวกับอะไร):\n   "ปริมาณประชากรเฉลี่ยต่อเมืองแยกตามภูมิภาค"\n\n2. Insight-driven Title (บอกข้อสรุปหลักพร้อมตัวเลข):\n   f"{max_region} ครองอันดับ 1 มีประชากรเฉลี่ยต่อเมืองสูงที่สุดอยู่ที่ {max_val:.1f} ล้านคน"\n'

# %% [markdown]
# ### ข้อ 6: ท้าทายเพิ่มเติม (Challenge) — Storytelling แบบสมบูรณ์
# จงเลือกคำถามที่น่าสนใจของตัวเอง 1 คำถามเกี่ยวกับข้อมูลนี้ (เช่น "เมืองไหนมีความเสี่ยงด้านสภาพอากาศรุนแรงมากที่สุด" หรือคำถามอื่นที่สนใจ) แล้วสร้าง Storytelling แบบ 3 ขั้นตอน (Context → Evidence → Conclusion) ให้ครบ:
# 1. เขียน Context อธิบายคำถามที่จะตอบ (เป็น markdown cell หรือ print ก็ได้)
# 2. สร้างกราฟอย่างน้อย 2 กราฟที่ค่อยๆ คลี่คลายคำถามนั้น (เรียงจากภาพรวมไปสู่รายละเอียด)
# 3. เขียน Conclusion สรุปสิ่งที่ค้นพบและข้อเสนอแนะ (ถ้ามี)

# %%
# เขียนคำตอบข้อ 6 ที่นี่
"""
### 📌 Context: คำถามวิจัย
"เมืองใดมีความเสี่ยงต่อสภาพอากาศสุดขั้ว (Extreme Weather Event) สูงที่สุด และพฤติกรรมสภาพอากาศเป็นอย่างไร?"
ที่มา: ต้องการวิเคราะห์เมืองที่มีลมพายุแรงรุนแรงร่วมกับปริมาณฝนตกสะสมสูง เพื่อการเตรียมรับมือภัยพิบัติ
"""

# --- STEP 2: EVIDENCE (2 กราฟ) ---
city_stats = (
    data.groupby(["region", "city"])
    .agg(
        avg_rainfall=("rainfall_mm", "mean"),
        max_wind=("wind_speed_kmh", "max"),
        pop=("population_millions", "first"),
    )
    .reset_index()
)

top_risk_city = city_stats.sort_values(
    by=["max_wind", "avg_rainfall"], ascending=False
).iloc[0]
target_city = top_risk_city["city"]

# Evidence Graph 1: ภาพรวมความเสี่ยง
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=city_stats,
    x="avg_rainfall",
    y="max_wind",
    hue="region",
    size="pop",
    sizes=(50, 400),
    palette="deep",
    alpha=0.8,
)

plt.annotate(
    f"⚠️ เมืองเสี่ยงสูงสุด: {target_city}",
    xy=(top_risk_city["avg_rainfall"], top_risk_city["max_wind"]),
    xytext=(
        top_risk_city["avg_rainfall"] - 5,
        top_risk_city["max_wind"] + 3,
    ),
    arrowprops=dict(facecolor="crimson", shrink=0.05, width=1.5, headwidth=8),
    fontsize=11,
    fontweight="bold",
    color="crimson",
)
plt.title(
    "1. ภาพรวม: การประเมินความเสี่ยงจากความเร็วลมสูงสุดและปริมาณฝนเฉลี่ย",
    fontsize=13,
    fontweight="bold",
    pad=15,
)
plt.xlabel("ปริมาณฝนเฉลี่ย (mm)")
plt.ylabel("ความเร็วลมสูงสุดที่เคยบันทึกได้ (km/h)")
plt.tight_layout()
plt.show()

# Evidence Graph 2: เจาะลึกเฉพาะเมืองเสี่ยงสูงสุด
city_daily = data[data["city"] == target_city].sort_values("date").head(60)

fig, ax1 = plt.subplots(figsize=(12, 5))
color = "steelblue"
ax1.set_xlabel("วันที่", fontsize=11)
ax1.set_ylabel("ปริมาณฝน (mm)", color=color, fontsize=11)
ax1.bar(city_daily["date"], city_daily["rainfall_mm"], color=color, alpha=0.5)
ax1.tick_params(axis="y", labelcolor=color)

ax2 = ax1.twinx()
color = "firebrick"
ax2.set_ylabel("ความเร็วลม (km/h)", color=color, fontsize=11)
ax2.plot(
    city_daily["date"],
    city_daily["wind_speed_kmh"],
    color=color,
    linewidth=2,
    marker="o",
    markersize=3,
)
ax2.tick_params(axis="y", labelcolor=color)

plt.title(
    f"2. เจาะลึกเมือง {target_city}: พฤติกรรมความเร็วลมและปริมาณฝนในแต่ละวัน",
    fontsize=13,
    fontweight="bold",
    pad=15,
)
plt.xticks(rotation=30)
fig.tight_layout()
plt.show()

# --- STEP 3: CONCLUSION ---
"""
### 💡 Conclusion: สรุปผลและข้อเสนอแนะ
1. สิ่งที่ค้นพบ: เมืองที่มีความเสี่ยงสูงสุดคือ {target_city} เนื่องจากมีทั้งค่าความเร็วลมพัดแรงสูงสุด และปริมาณฝนตกสะสมเฉลี่ยสูงกว่าเมืองอื่นอย่างเห็นได้ชัด
2. ข้อเสนอแนะ: ควรเร่งติดตั้งระบบเตือนภัยพายุล่วงหน้าในเมือง {target_city} และเสริมความแข็งแรงของสิ่งปลูกสร้างในเขตชุมชนเพื่อลดความเสียหาย
"""
# Out:
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3603 (\N{THAI CHARACTER NO NEN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3613 (\N{THAI CHARACTER FO FA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3593 (\N{THAI CHARACTER CHO CHING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3655 (\N{THAI CHARACTER MAITAIKHU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3640 (\N{THAI CHARACTER SARA U}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3604 (\N{THAI CHARACTER DO DEK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3607 (\N{THAI CHARACTER THO THAHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3610 (\N{THAI CHARACTER BO BAIMAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3638 (\N{THAI CHARACTER SARA UE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3652 (\N{THAI CHARACTER SARA AI MAIMALAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3657 (\N{THAI CHARACTER MAI THO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3614 (\N{THAI CHARACTER PHO PHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3639 (\N{THAI CHARACTER SARA UEE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:57: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3655 (\N{THAI CHARACTER MAITAIKHU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3640 (\N{THAI CHARACTER SARA U}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3604 (\N{THAI CHARACTER DO DEK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3607 (\N{THAI CHARACTER THO THAHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3610 (\N{THAI CHARACTER BO BAIMAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3638 (\N{THAI CHARACTER SARA UE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3652 (\N{THAI CHARACTER SARA AI MAIMALAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3657 (\N{THAI CHARACTER MAI THO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3616 (\N{THAI CHARACTER PHO SAMPHAO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3614 (\N{THAI CHARACTER PHO PHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3603 (\N{THAI CHARACTER NO NEN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3613 (\N{THAI CHARACTER FO FA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3593 (\N{THAI CHARACTER CHO CHING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3639 (\N{THAI CHARACTER SARA UEE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3607 (\N{THAI CHARACTER THO THAHAN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3603 (\N{THAI CHARACTER NO NEN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3613 (\N{THAI CHARACTER FO FA}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3655 (\N{THAI CHARACTER MAITAIKHU}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3638 (\N{THAI CHARACTER SARA UE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3639 (\N{THAI CHARACTER SARA UEE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3614 (\N{THAI CHARACTER PHO PHAN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3620 (\N{THAI CHARACTER RU}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3605 (\N{THAI CHARACTER TO TAO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /tmp/ipykernel_4799/2279087959.py:90: UserWarning: Glyph 3651 (\N{THAI CHARACTER SARA AI MAIMUAN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3620 (\N{THAI CHARACTER RU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3605 (\N{THAI CHARACTER TO TAO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3651 (\N{THAI CHARACTER SARA AI MAIMUAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# '\n### 💡 Conclusion: สรุปผลและข้อเสนอแนะ\n1. สิ่งที่ค้นพบ: เมืองที่มีความเสี่ยงสูงสุดคือ {target_city} เนื่องจากมีทั้งค่าความเร็วลมพัดแรงสูงสุด และปริมาณฝนตกสะสมเฉลี่ยสูงกว่าเมืองอื่นอย่างเห็นได้ชัด\n2. ข้อเสนอแนะ: ควรเร่งติดตั้งระบบเตือนภัยพายุล่วงหน้าในเมือง {target_city} และเสริมความแข็งแรงของสิ่งปลูกสร้างในเขตชุมชนเพื่อลดความเสียหาย\n'

# %% [markdown]
# ---
# ## 🔗 เชื่อม Colab กับ GitHub
#
# เก็บ Notebook นี้ขึ้น GitHub ต่อจากไฟล์ก่อนหน้า
#
# ### วิธีที่ 1: เซฟจาก Colab ขึ้น GitHub ตรงๆ (สำหรับ Notebook)
#
# 1. ใน Colab ไปที่เมนู **File → Save a copy in GitHub**
# 2. เลือก repository เดิมที่ใช้เก็บ Notebook คาบก่อนๆ (เช่น `SC612104-coursework`)
# 3. ตั้งชื่อไฟล์และ commit message (เช่น `"เพิ่ม notebook: data visualization (matplotlib/seaborn/storytelling)"`) แล้วกด **OK**
#
# ### วิธีที่ 2: ใช้ Git ผ่าน Terminal
#
# ```bash
# git clone https://github.com/<username>/<repo-name>.git
# cd <repo-name>
# git add notebook.ipynb
# git commit -m "เพิ่ม notebook: data visualization"
# git push origin main
# ```
#
# > 💡 **Tip:** ทักษะการเลือกกราฟให้เหมาะสมและตั้งชื่อให้สื่อความหมาย มักสำคัญกว่าทักษะการเขียนโค้ดสร้างกราฟเสียอีก — นักวิเคราะห์ข้อมูลที่ดีคือคนที่รู้ว่า "จะแสดงอะไร" และ "ทำไมต้องแสดงสิ่งนั้น" ไม่ใช่แค่รู้คำสั่งสร้างกราฟทุกแบบ ลองฝึกตั้งคำถามกับข้อมูลก่อนเปิดคอมพิวเตอร์สร้างกราฟทุกครั้ง จะช่วยให้กราฟที่ได้มีจุดมุ่งหมายชัดเจนกว่าการลองสร้างกราฟทุกแบบแล้วดูว่าอันไหนสวย
